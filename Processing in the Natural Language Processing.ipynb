# %% [markdown]
# ##  1. Basic NLP processing in the Natural Language Processing - NLP course by Hercules Dalianis

# %% [markdown]
# Download the BBB Politics and Business corpus
# http://people.dsv.su.se/hercules/BBC_politics_business.txt
# and put in a folder called NLP-lab1

# %%
# Start Jupiter notebook or your Python interpreted and open the
# Corpus file

corpusFilePointer = open("BBC_politics_business.txt")

# %%
corpusText = corpusFilePointer.read()
corpusFilePointer.close()

# %%
# Import NLTK library

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Tokenize the Corpus using the nltk.word_tokenize()
corpus_tokenized =  nltk.word_tokenize(corpusText)

# %%
# 1)
# Calculate the number of tokens in the corpus.
# Think about it as length of a list.
# Calculate the lenght of the corpus
len(corpus_tokenized)
# Out:
# 84337

# %%
# 2)
# Calculate the number of unique tokens (types) there are in the corpus.
# "This is a token. This is another token." There are two occurancies of "token" in the previous
# string but one type "token".
# To calculate the types think about the set() function
num_unique_tokens = len(set(corpus_tokenized))
num_unique_tokens
# Out:
# 9763

# %%
# Import the predefined stopwords in NLTK
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# 3)
# How many stopword are there in the stop word list?
# Are this few or many stop words, can you think about
# other stopwords?
len(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 179

# %%
# Write a Python function that filters out the stopwords from
# the BBC corpus
def filter_stopwords(corpus_tokenized):
    return [word for word in corpus_tokenized if word not in stop_words]

stopfilteredCorpus = filter_stopwords(corpus_tokenized)

# %%
# 4)
# How many tokens are there in the BBC corpus after filter out the stopwords
# are these reasonable or to many or too few?
num_tokens_after_stopwords = len(stopfilteredCorpus)
num_tokens_after_stopwords
# Out:
# 56299

# %%
# Check if all stopwords really were removed from the BBC corpus
# Can you write a Python function that also matches initial uppercase stopwords
def filter_stopwords_lower(corpus_tokenized):
    return [word for word in corpus_tokenized if word.lower() not in stop_words]

stopfilteredCorpus = filter_stopwords_lower(corpus_tokenized)

# %%
# 5)
# How many tokens are there in the BBC corpus after filtering also
# in lower case?
num_tokens_after_stopwordsLower = len(stopfilteredCorpus)
num_tokens_after_stopwordsLower
# Out:
# 54006

# %%
# 6)
# How many types (unique) do you have now?
num_types_lowercase = len(set(stopfilteredCorpus))
num_types_lowercase
# Out:
# 9565

# %%
# Import the WordNet lemmatizer in NLTK
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Write a Python function that lemmatizes the tokens in the BBC corpus
def lemmatize_tokens(corpus):
    return [lemmatizer.lemmatize(word) for word in corpus]

# Lemmatize the tokens and calculate the number of types
lemmatizedCorpus = lemmatize_tokens(stopfilteredCorpus)

# %%
# 7)
# How many types do you have in the BBC corpus after lemmatization?
num_types_after_lemmatization = len(set(lemmatizedCorpus))
num_types_after_lemmatization
# Out:
# 8815

# %%
#from nltk.stem import PorterStemmer
stemmer = nltk.stem.PorterStemmer()

# %%
# Write a Python function that stems the tokens in the BBC corpus
stemmedCorpus = []
for w in stopfilteredCorpus:
    stemmedCorpus.append(stemmer.stem(w))

# %%
# 8)
# How many types do you have in the BBC Corpus after stemming?
# Are there any differences? If so, why?
len(stemmedCorpus)
len(set(stemmedCorpus))
# Out:
# 6506

# %% [markdown]
# ### Now we are ready with the corpus linguistic part of the laboration exercise and we start with POS taggning and Chunking which is more NLP processing tasks.

# %%
# Use the nltk.pos_tag() function to POS tag the BBC corpus
nltk.download('averaged_perceptron_tagger')
tokenCorpus = nltk.word_tokenize(corpusText)

pos_tagged_corpus = nltk.pos_tag(tokenCorpus)
pos_tagged_corpus
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Prime', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Tony', 'NNP'),
#  ('Blair', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('announce', 'VB'),
#  ('new', 'JJ'),
#  ('measures', 'NNS'),
#  ('to', 'TO'),
#  ('strengthen', 'VB'),
#  ('the', 'DT'),
#  ('use', 'NN'),
#  ('of', 'IN'),
#  ('Asbos', 'NNP'),
#  ('and', 'CC'),
#  ('fixed', 'VBD'),
#  ('penalty', 'NN'),
#  ('notices', 'NNS'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('still', 'RB'),
#  ('concerns', 'NNS'),
#  ('that', 'IN'),
#  ('some', 'DT'),
#  ('areas', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('powers', 'NNS'),
#  ('properly', 'RB'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('say', 'VB'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('new', 'JJ'),
#  ('figures', 'NNS'),
#  ('were', 'VBD'),
#  ('heartening', 'VBG'),
#  ('but', 'CC'),
#  ('he', 'PRP'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('rest', 'VB'),
#  ('until', 'IN'),
#  ('similar', 'JJ'),
#  ('action', 'NN'),
#  ('was', 'VBD'),
#  ('taken', 'VBN'),
#  ('in', 'IN'),
#  ('all', 'DT'),
#  ('areas', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('where', 'WRB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('needed', 'VBN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('not', 'RB'),
#  ('defeated', 'VBN'),
#  ('this', 'DT'),
#  ('problem', 'NN'),
#  ('by', 'IN'),
#  ('any', 'DT'),
#  ('means', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('shown', 'VBN'),
#  ('together', 'RB'),
#  ('what', 'WP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('done', 'VBN'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('will', 'MD'),
#  ('say', 'VB'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('Blair', 'NNP'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('defended', 'VBD'),
#  ('the', 'DT'),
#  ('shake-up', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('licensing', 'NN'),
#  ('laws', 'NNS'),
#  (',', ','),
#  ('saying', 'VBG'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('right', 'JJ'),
#  ('to', 'TO'),
#  ('focus', 'VB'),
#  ('on', 'IN'),
#  ('troublemakers', 'NNS'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('treating', 'VBG'),
#  ('everybody', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('potential', 'JJ'),
#  ('drunken', 'NN'),
#  ('nuisance', 'NN'),
#  ('.', '.'),
#  ('Ministers', 'NNS'),
#  ('also', 'RB'),
#  ('boast', 'IN'),
#  ('of', 'IN'),
#  ('record', 'NN'),
#  ('police', 'NN'),
#  ('numbers', 'NNS'),
#  ('and', 'CC'),
#  ('are', 'VBP'),
#  ('speeding', 'VBG'),
#  ('up', 'RP'),
#  ('plans', 'NNS'),
#  ('to', 'TO'),
#  ('put', 'VB'),
#  ('in', 'IN'),
#  ('place', 'NN'),
#  ('25,000', 'CD'),
#  ('community', 'NN'),
#  ('support', 'NN'),
#  ('officers', 'NNS'),
#  ('(', '('),
#  ('CSOs', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('researchers', 'NNS'),
#  ('from', 'IN'),
#  ('Leeds', 'NNP'),
#  ('University', 'NNP'),
#  ('warned', 'VBD'),
#  ('that', 'IN'),
#  ('CSOs', 'NNP'),
#  ('could', 'MD'),
#  ('undermine', 'VB'),
#  ('traditional', 'JJ'),
#  ('bonds', 'NNS'),
#  ('between', 'IN'),
#  ('police', 'NN'),
#  ('officers', 'NNS'),
#  ('and', 'CC'),
#  ('communities', 'NNS'),
#  ('.', '.'),
#  ('More', 'JJR'),
#  ('work', 'NN'),
#  ('needed', 'VBN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('done', 'VBN'),
#  ('on', 'IN'),
#  ('clarifying', 'VBG'),
#  ('the', 'DT'),
#  ('role', 'NN'),
#  ('of', 'IN'),
#  ('different', 'JJ'),
#  ('agencies', 'NNS'),
#  ('and', 'CC'),
#  ('how', 'WRB'),
#  ('they', 'PRP'),
#  ('linked', 'VBD'),
#  ('together', 'RB'),
#  ('before', 'IN'),
#  ('CSOs', 'NNP'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('argued', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('the', 'DT'),
#  ('study', 'NN'),
#  ('.', '.'),
#  ('Critics', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('say', 'VBP'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('announced', 'VBN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('20', 'CD'),
#  ('initiatives', 'NNS'),
#  ('to', 'TO'),
#  ('tackle', 'VB'),
#  ('nuisance', 'RB'),
#  ('behaviour', 'NN'),
#  ('when', 'WRB'),
#  ('the', 'DT'),
#  ('real', 'JJ'),
#  ('focus', 'NN'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('on', 'IN'),
#  ('good', 'JJ'),
#  ('policing', 'NN'),
#  ('.', '.'),
#  ('Home', 'NNP'),
#  ('Office', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Hazel', 'NNP'),
#  ('Blears', 'NNP'),
#  ('also', 'RB'),
#  ('revealed', 'VBD'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('that', 'IN'),
#  ('``', '``'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('third', 'JJ'),
#  ("''", "''"),
#  ('of', 'IN'),
#  ('Asbos', 'NNP'),
#  ('were', 'VBD'),
#  ('breached', 'VBN'),
#  ('-', ':'),
#  ('with', 'IN'),
#  ('some', 'DT'),
#  ('people', 'NNS'),
#  ('jailed', 'VBN'),
#  ('and', 'CC'),
#  ('others', 'NNS'),
#  ('not', 'RB'),
#  ('.', '.'),
#  ('Kennedy', 'NNP'),
#  ('calls', 'VBZ'),
#  ('for', 'IN'),
#  ('Iraq', 'NNP'),
#  ('exit', 'NN'),
#  ('plans', 'NNS'),
#  ('Tony', 'NNP'),
#  ('Blair', 'NNP'),
#  ('should', 'MD'),
#  ('set', 'VB'),
#  ('out', 'RP'),
#  ('a', 'DT'),
#  ('proper', 'JJ'),
#  ('exit', 'NN'),
#  ('strategy', 'NN'),
#  ('from', 'IN'),
#  ('Iraq', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wake', 'NN'),
#  ('of', 'IN'),
#  ('next', 'JJ'),
#  ('Sunday', 'NNP'),
#  ("'s", 'POS'),
#  ('elections', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  (',', ','),
#  ('Lib', 'NNP'),
#  ('Dem', 'NNP'),
#  ('leader', 'NN'),
#  ('Charles', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('a', 'DT'),
#  ('speech', 'NN'),
#  ('focusing', 'VBG'),
#  ('on', 'IN'),
#  ('issues', 'NNS'),
#  ('arising', 'VBG'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('re-election', 'NN'),
#  ('of', 'IN'),
#  ('George', 'NNP'),
#  ('W', 'NNP'),
#  ('Bush', 'NNP'),
#  (',', ','),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('said', 'VBD'),
#  ('Iraq', 'NNP'),
#  ('had', 'VBD'),
#  ('become', 'VBN'),
#  ('a', 'DT'),
#  ('``', '``'),
#  ('crucible', 'JJ'),
#  ('of', 'IN'),
#  ('militant', 'JJ'),
#  ('terrorism', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('wants', 'VBZ'),
#  ('to', 'TO'),
#  ('see', 'VB'),
#  ('a', 'DT'),
#  ('phased', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('of', 'IN'),
#  ('UK', 'NNP'),
#  ('troops', 'VBZ'),
#  ('``', '``'),
#  ('as', 'RB'),
#  ('soon', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('situation', 'NN'),
#  ('allows', 'VBZ'),
#  ("''", "''"),
#  (',', ','),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('London', 'NNP'),
#  ('.', '.'),
#  ('Any', 'NNP'),
#  ('exit', 'NN'),
#  ('strategy', 'NN'),
#  ('must', 'MD'),
#  ('``', '``'),
#  ('augment', 'NN'),
#  ('and', 'CC'),
#  ('support', 'NN'),
#  ("''", "''"),
#  ('the', 'DT'),
#  ('democratic', 'JJ'),
#  ('process', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('some', 'DT'),
#  ('who', 'WP'),
#  ('are', 'VBP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('opinion', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('mere', 'JJ'),
#  ('presence', 'NN'),
#  ('of', 'IN'),
#  ('British', 'JJ'),
#  ('and', 'CC'),
#  ('American', 'JJ'),
#  ('troops', 'NNS'),
#  ('in', 'IN'),
#  ('Iraq', 'NNP'),
#  ('feeds', 'VBZ'),
#  ('the', 'DT'),
#  ('insurgency', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('some', 'DT'),
#  ('truth', 'NN'),
#  ('in', 'IN'),
#  ('that', 'DT'),
#  (',', ','),
#  ('especially', 'RB'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('initial', 'JJ'),
#  ('mistakes', 'NNS'),
#  ('that', 'WDT'),
#  ('were', 'VBD'),
#  ('made', 'VBN'),
#  ('-', ':'),
#  ('the', 'DT'),
#  ('heavy-handedness', 'NN'),
#  ('of', 'IN'),
#  ('operations', 'NNS'),
#  ('like', 'IN'),
#  ('Fallujah', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('well-publicised', 'JJ'),
#  ('instances', 'NNS'),
#  ('of', 'IN'),
#  ('abuse', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('hands', 'NNS'),
#  ('of', 'IN'),
#  ('coalition', 'NN'),
#  ('forces', 'NNS'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('pointed', 'VBD'),
#  ('out', 'RP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('Netherlands', 'NNP'),
#  (',', ','),
#  ('Portugal', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Czech', 'NNP'),
#  ('Republic', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('all', 'DT'),
#  ('have', 'VBP'),
#  ('troops', 'NNS'),
#  ('operating', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('southern', 'JJ'),
#  ('sector', 'NN'),
#  ('of', 'IN'),
#  ('Iraq', 'NNP'),
#  (',', ','),
#  ('have', 'VBP'),
#  ('announced', 'VBN'),
#  ('their', 'PRP$'),
#  ('imminent', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('``', '``'),
#  ('regardless', 'RB'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('situation', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('ground', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('accused', 'VBD'),
#  ('Mr', 'NNP'),
#  ('Blair', 'NNP'),
#  ("'s", 'POS'),
#  ('government', 'NN'),
#  ('of', 'IN'),
#  ('``', '``'),
#  ('being', 'VBG'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('straightforward', 'NN'),
#  ("''", "''"),
#  ('over', 'IN'),
#  ('its', 'PRP$'),
#  ('plans', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Next', 'JJ'),
#  ('week', 'NN'),
#  ('the', 'DT'),
#  ('prime', 'JJ'),
#  ('minister', 'NN'),
#  ('should', 'MD'),
#  ('make', 'VB'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('regarding', 'VBG'),
#  ('the', 'DT'),
#  ('elections', 'NNS'),
#  ('in', 'IN'),
#  ('Iraq', 'NNP'),
#  (',', ','),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('said', 'VBD'),
#  ('during', 'IN'),
#  ('his', 'PRP$'),
#  ('City', 'NNP'),
#  ('of', 'IN'),
#  ('London', 'NNP'),
#  ('speech', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('He', 'PRP'),
#  ('should', 'MD'),
#  ('set', 'VB'),
#  ('out', 'RP'),
#  ('a', 'DT'),
#  ('proper', 'JJ'),
#  ('exit', 'NN'),
#  ('strategy', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('the', 'DT'),
#  ('phased', 'JJ'),
#  ('withdrawal', 'NN'),
#  ('of', 'IN'),
#  ('British', 'JJ'),
#  ('troops', 'NNS'),
#  (',', ','),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('security', 'NN'),
#  ('situation', 'NN'),
#  ('allows', 'VBZ'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('Kennedy', 'NNP'),
#  ('also', 'RB'),
#  ('argued', 'VBD'),
#  ('that', 'IN'),
#  ('British', 'JJ'),
#  ('troops', 'NNS'),
#  ('deployed', 'VBN'),
#  ('in', 'IN'),
#  ('Iraq', 'NNP'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('replaced', 'VBN'),
#  ('with', 'IN'),
#  ('forces', 'NNS'),
#  ('from', 'IN'),
#  ('other', 'JJ'),
#  ('countries', 'NNS'),
#  ('-', ':'),
#  ('``', '``'),
#  ('especially', 'RB'),
#  ('Islamic', 'JJ'),
#  ('countries', 'NNS'),
#  ("''", "''"),
#  ('.', '.'),
#  ('McConnell', 'NNP'),
#  ('in', 'IN'),
#  ("'drunk", 'NNP'),
#  ("'", 'POS'),
#  ('remark', 'NN'),
#  ('row', 'NN'),
#  ('Scotland', 'NNP'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('minister', 'NN'),
#  ('has', 'VBZ'),
#  ('told', 'VBN'),
#  ('a', 'DT'),
#  ('group', 'NN'),
#  ('of', 'IN'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('pupils', 'NNS'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('okay', 'VBN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('drunk', 'JJ'),
#  ('``', '``'),
#  ('once', 'RB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('while', 'NN'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Jack', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('to', 'TO'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('100', 'CD'),
#  ('secondary', 'JJ'),
#  ('pupils', 'NNS'),
#  ('from', 'IN'),
#  ('schools', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Highlands', 'NNS'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('problems', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('drink', 'NN'),
#  ('promotions', 'NNS'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('criticised', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('SNP', 'NNP'),
#  ('for', 'IN'),
#  ('encouraging', 'VBG'),
#  ('young', 'JJ'),
#  ('people', 'NNS'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('drunk', 'JJ'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('the', 'DT'),
#  ('Scottish', 'NNP'),
#  ('Executive', 'NNP'),
#  ('has', 'VBZ'),
#  ('insisted', 'VBN'),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('about', 'IN'),
#  ('adults', 'NNS'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('comments', 'NNS'),
#  ('were', 'VBD'),
#  ('``', '``'),
#  ('a', 'DT'),
#  ('recognition', 'NN'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('drunk', 'JJ'),
#  ("''", "''"),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('first', 'JJ'),
#  ('minister', 'NN'),
#  ("'s", 'POS'),
#  ('comments', 'NNS'),
#  ('came', 'VBD'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('question', 'NN'),
#  ('and', 'CC'),
#  ('answer', 'NN'),
#  ('session', 'NN'),
#  ('at', 'IN'),
#  ('Glenurquhart', 'NNP'),
#  ('High', 'NNP'),
#  ('School', 'NNP'),
#  ('in', 'IN'),
#  ('Inverness', 'NNP'),
#  (',', ','),
#  ('attended', 'VBN'),
#  ('by', 'IN'),
#  ('pupils', 'NNS'),
#  ('from', 'IN'),
#  ('a', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('secondary', 'JJ'),
#  ('schools', 'NNS'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('Highland', 'NNP'),
#  ('councillor', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('event', 'NN'),
#  ('has', 'VBZ'),
#  ('also', 'RB'),
#  ('defended', 'VBN'),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('.', '.'),
#  ('Margaret', 'NNP'),
#  ('Davidson', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('independent', 'JJ'),
#  ('member', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('Loch', 'NNP'),
#  ('Ness', 'NNP'),
#  ('West', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('minister', 'NN'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('general', 'JJ'),
#  ('way', 'NN'),
#  ('and', 'CC'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('sure', 'RB'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('speaking', 'VBG'),
#  ('about', 'IN'),
#  ('adults', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('one', 'CD'),
#  ('pupil', 'NN'),
#  ('asked', 'VBD'),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('how', 'WRB'),
#  ('the', 'DT'),
#  ('executive', 'NN'),
#  ('proposed', 'VBD'),
#  ('to', 'TO'),
#  ('tackle', 'VB'),
#  ('under-age', 'JJ'),
#  ('drinking', 'NN'),
#  (',', ','),
#  ('began', 'VBD'),
#  ('his', 'PRP$'),
#  ('response', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('quip', 'NN'),
#  (':', ':'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('sure', 'JJ'),
#  ('there', 'EX'),
#  ("'s", 'VBZ'),
#  ('no', 'DT'),
#  ('under-age', 'JJ'),
#  ('drinking', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Highlands', 'NNP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('He', 'PRP'),
#  ('went', 'VBD'),
#  ('on', 'IN'),
#  ('to', 'TO'),
#  ('speak', 'VB'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('evils', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('railed', 'VBN'),
#  ('against', 'IN'),
#  ('irresponsible', 'JJ'),
#  ('drinks', 'NNS'),
#  ('promotions', 'NNS'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  (':', ':'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('hope', 'VBP'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('not', 'RB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('seen', 'VBN'),
#  ('as', 'IN'),
#  ('preaching', 'VBG'),
#  ('to', 'TO'),
#  ('anybody', 'NN'),
#  ('here', 'RB'),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('really', 'RB'),
#  ('serious', 'JJ'),
#  ('problem', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('moment', 'NN'),
#  ('is', 'VBZ'),
#  ('binge', 'JJ'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('impact', 'NN'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('on', 'IN'),
#  ('people', 'NNS'),
#  ("'s", 'POS'),
#  ('health', 'NN'),
#  ('and', 'CC'),
#  ('their', 'PRP$'),
#  ('ability', 'NN'),
#  ('to', 'TO'),
#  ('control', 'VB'),
#  ('what', 'WP'),
#  ("'s", 'VBZ'),
#  ('happening', 'VBG'),
#  ('round', 'NN'),
#  ('about', 'IN'),
#  ('them', 'PRP'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Mr', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('regularly', 'RB'),
#  ('saw', 'VBD'),
#  ('reports', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('effects', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('sprees', 'NNS'),
#  ('which', 'WDT'),
#  ('ended', 'VBD'),
#  ('in', 'IN'),
#  ('assaults', 'NNS'),
#  ('or', 'CC'),
#  ('even', 'RB'),
#  ('rapes', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('health', 'NN'),
#  ('consequences', 'NNS'),
#  ('of', 'IN'),
#  ('binge', 'NN'),
#  ('drinking', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('one', 'CD'),
#  ('thing', 'NN'),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('something', 'NN'),
#  ('really', 'RB'),
#  ('serious', 'JJ'),
#  ('about', 'IN'),
#  ('is', 'VBZ'),
#  ('binge', 'JJ'),
#  ('drinking', 'NN'),
#  ('and', 'CC'),
#  ('irresponsible', 'JJ'),
#  ('drinks', 'NNS'),
#  ('promotions', 'NNS'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('help', 'VB'),
#  ('lead', 'VB'),
#  ('to', 'TO'),
#  ('that', 'DT'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Far', 'NNP'),
#  ('too', 'RB'),
#  ('many', 'JJ'),
#  ('pub', 'NN'),
#  ('chains', 'NNS'),
#  ('in', 'IN'),
#  ('particular', 'JJ'),
#  ('are', 'VBP'),
#  ('selling', 'VBG'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('much', 'JJ'),
#  ('booze', 'NN'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('cheaply', 'JJ'),
#  ('and', 'CC'),
#  ('encouraging', 'JJ'),
#  ('people', 'NNS'),
#  ('to', 'TO'),
#  ('drink', 'VB'),
#  ('it', 'PRP'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('quickly', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('are', 'VBP'),
#  ('go', 'VB'),
#  ('to', 'TO'),
#  ('clamp', 'VB'),
#  ('down', 'RP'),
#  ('on', 'IN'),
#  ('that', 'DT'),
#  ('and', 'CC'),
#  ('make', 'VB'),
#  ('those', 'DT'),
#  ('promotions', 'NNS'),
#  ('illegal', 'VBP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('hope', 'NN'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('can', 'MD'),
#  ('enjoy', 'VB'),
#  ('a', 'DT'),
#  ('drink', 'NN'),
#  ('sensibly', 'RB'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('course', 'NN'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('evening', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('He', 'PRP'),
#  ('added', 'VBD'),
#  (':', ':'),
#  ('``', '``'),
#  ('By', 'IN'),
#  ('all', 'DT'),
#  ('means', 'NNS'),
#  ('get', 'VBP'),
#  ('drunk', 'JJ'),
#  ('once', 'RB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('while', 'NN'),
#  ('-', ':'),
#  ('but', 'CC'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('get', 'VB'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('situation', 'NN'),
#  ('where', 'WRB'),
#  ('people', 'NNS'),
#  ('are', 'VBP'),
#  ('being', 'VBG'),
#  ('encouraged', 'VBN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('completely', 'RB'),
#  ('incapable', 'JJ'),
#  ('just', 'RB'),
#  ('to', 'TO'),
#  ('save', 'VB'),
#  ('some', 'DT'),
#  ('money', 'NN'),
#  ('and', 'CC'),
#  ('drink', 'VB'),
#  ('more', 'JJR'),
#  ('quickly', 'RB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('SNP', 'NNP'),
#  ('Holyrood', 'NNP'),
#  ('leader', 'NN'),
#  ...]

# %% [markdown]
# 9)
# Inspect the tagged corpus, what types of tags do you see?
# What do they mean?

# %% [markdown]
# NNP proper noun sigular
# VB base form verb
# VBP past tense verb, not 3 person

# %% [markdown]
# Here follows an example with a short sentence to introduce chunking

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')
sent = ("Israeli Prime Minister Ehud Olmert is scheduled to meet with Palestinian President Mahmoud Abbas Wednesday in Jerusalem. Palestinian negotiator Saeb Erekat said the talks will focus on permanent- status issues, Israeli checkpoints and the fate of Palestinian prisoners. The meeting, at Mr. Olmert's official residence, will be the first between the two since Mr. Olmert announced that he will step down after his Kadima Party chooses a new leader in September. The two leaders re-started peace talks in November with the goal of reaching a deal by this year's end")

# Tokenisation
tokenised = nltk.word_tokenize(sent)

# Taggning
tagged = nltk.pos_tag(tokenised)

# Chunking
sentChunked = nltk.ne_chunk(tagged)

#PERSON, ORGANIZATION and GPE

#Print some named entities in the sentence
for n in sentChunked:
    if isinstance(n, nltk.tree.Tree):
        if n.label() == 'PERSON' or n.label() == 'ORGANIZATION' or n.label() == 'GPE':
            print(n)
        else:
            n
            #print(n)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# (GPE Israeli/JJ)
# (PERSON Ehud/NNP Olmert/NNP)
# (GPE Palestinian/NNP)
# (PERSON Mahmoud/NNP Abbas/NNP)
# (GPE Jerusalem/NNP)
# (GPE Palestinian/JJ)
# (PERSON Saeb/NNP Erekat/NNP)
# (GPE Israeli/JJ)
# (GPE Palestinian/JJ)
# (PERSON Mr./NNP Olmert/NNP)
# (PERSON Mr./NNP Olmert/NNP)
# (ORGANIZATION Kadima/NNP Party/NNP)

# %% [markdown]
# Use the function draw() to draw a chunktree (shallow parse tree),

# %%
#Draw
#sentChunked.draw()

# %% [markdown]
# 10)
# Count the number of Persons, Organisation and GPEs, Geo Political Entities in the BBC corpus. Follow the above example and extend the function.

# %% [markdown]
# The chunking of the BBC corpus takes some time, please be patient.

# %%
print('Chunking')
# Out:
# Chunking

# %%
# Chunking
chunked_corpus = nltk.ne_chunk(pos_tagged_corpus)

# %%
# Number of PERSON
num_persons = 0
for n in chunked_corpus:
    if isinstance(n, nltk.tree.Tree):
        if n.label() == 'PERSON':
            num_persons += 1
print('Number of PERSON:', num_persons)
# Out:
# Number of PERSON: 1886

# %%
# Number of ORGANIZATION
num_organizations = 0
for n in chunked_corpus:
    if isinstance(n, nltk.tree.Tree):
        if n.label() == 'ORGANIZATION':
            num_organizations += 1
print('Number of ORGANIZATION:', num_organizations)
# Out:
# CSOs
# CSOs
# CSOs
# UK
# Czech
# Islamic
# McConnell
# SNP
# Scottish
# McConnell
# Loch
# Highlands
# SNP
# McConnell
# First
# BBC
# Chancellor
# BBC
# Treasury
# Treasury
# Treasury
# Conservative
# MPs
# Welsh
# Conservatives
# MPs
# MPs
# Whitehall
# Parliament
# Commons
# Westminster
# United
# House
# UK
# Belmarsh
# Foreign
# Law
# Liberal
# Belmarsh
# BBC
# Liberal
# BBC
# Fraser
# Allander
# SNP
# Scottish
# Quarterly
# Strathclyde
# Allander
# BBC
# Scottish
# Scottish
# Labour
# Liberal
# MI6
# MI6
# UK
# MI6
# Liberal
# Foreign
# BBC
# Muslim
# Department
# Defense
# US
# UK
# UK
# Welsh
# WLGA
# WLGA
# Labour
# Liberal
# Tories
# Lib
# UK
# BBC
# BBC
# UK
# Children
# Commons
# Association
# Social
# ADSS
# ADSS
# HRH
# Cornwall
# Windsor
# Daily
# Princess
# Windsor
# Royal
# Queen
# Duke
# Archbishop
# Church
# Archbishop
# Liberal
# Islamic
# Islamic
# UK
# Commons
# Islamic
# IHRC
# Salford
# Commons
# Muslim
# IHRC
# UK
# Terrorism
# Muslim
# Muslim
# Tory
# Refugee
# UK
# Tory
# Liberal
# Conservatives
# NHS
# New
# BBC
# BBC
# Tory
# Transport
# General
# TGWU
# TGWU
# GMB
# TGWU
# Warwick
# BBC
# TGWU
# UK
# ICT
# UK
# HI
# UK
# ICT
# ICT
# ICT
# UK
# ICT
# ICT
# UK
# International
# ICT
# Conservative
# Tories
# UK
# Veritas
# UKIP
# Defence
# Ashfield
# UKIP
# London
# UKIP
# UKIP
# Leicestershire
# UKIP
# AWOL
# UKIP
# UKIP
# UKIP
# London
# UK
# UKIP
# Eurosceptic
# UKIP
# UK
# UKIP
# UKIP
# UKIP
# UKIP
# English
# New
# UKIP
# UKIP
# RKS
# Veritas
# YouGov
# Cabinet
# Blunkett
# Conservatives
# Liberal
# CommunicateResearch
# Euston
# Green
# University
# Parliamentary
# Transport
# MPs
# UK
# Transport
# BAC
# AA
# Liberal
# Road
# Labour
# Times
# Transport
# CSA
# Child
# CSA
# Commons
# CSA
# CSA
# Parliament
# CS2
# BBC
# MPs
# CSA
# MPs
# EDS
# CSA
# CSA
# National
# EDS
# House
# Lords
# Commons
# BBC
# Lords
# Lords
# Commons
# BBC1
# Commons
# House
# Cabinet
# House
# House
# Department
# Constitutional
# BBC
# House
# Parliament
# House
# House
# Parliament
# Law
# Lord
# Lords
# Lord
# Human
# Family
# Merseyside
# Commission
# Nazi
# Prince
# Prince
# ITV
# Nazis
# Nazis
# Sun
# Nazi
# BBC
# Buckingham
# Hospital
# New
# BMA
# Welsh
# Social
# Welsh
# Audit
# UK
# Tuberculosis
# HIV
# Conservatives
# TB
# HIV
# NHS
# Lib
# Conservatives
# General
# UK
# BBC
# UK
# NHS
# TB
# HIV
# TB
# Heathrow
# Lung
# UK
# Liberal
# Labour
# Conservatives
# Aids
# Terrence
# MPs
# MPs
# Commons
# MPs
# Commons
# Commons
# House
# Liberal
# AM
# NHS
# NHS
# NHS
# NHS
# BBC
# NHS
# NHS
# Plaid
# Lib
# MPs
# Welsh
# UKIP
# UKIP
# UKIP
# MEP
# UKIP
# BBC
# Herald
# UKIP
# Times
# US
# United
# UK
# UK
# BBC
# Doha
# European
# Common
# Catholic
# Aids
# Tories
# MPs
# Liberal
# UK
# Lib
# National
# BBC
# European
# National
# Federation
# Small
# Ivory
# Aids
# Department
# International
# International
# UK
# High
# RAF
# Appeal
# High
# RAF
# Lord
# Gloucestershire
# RAF
# UK
# RAF
# Fairford
# European
# Human
# Liberty
# Tories
# Lib
# Lib
# MP
# BBC
# Commons
# Parliament
# Countryside
# Countryside
# Public
# House
# Lords
# League
# Beaufort
# Conservatives
# UK
# UK
# Foreign
# Tsunami
# BBC
# UK
# Sri
# International
# RAF
# Royal
# HMS
# Bayleaf
# BBC
# BBC
# BBC
# European
# Conservatives
# Foreign
# Zimbabwe
# BBC
# One
# UK
# Nato
# Countryside
# League
# BBC
# Postbridge
# BBC
# Beaufort
# BBC
# Leicestershire
# Countryside
# Association
# UK
# National
# European
# Auditors
# NAO
# European
# Community
# Commons
# UK
# Community
# UK
# Commission
# European
# NAO
# NAO
# UK
# Line
# Control
# Line
# Control
# Golden
# Sindh
# Department
# International
# Survivors
# SURF
# ID
# Labour
# Tory
# Lib
# ID
# Conservatives
# BBC
# ID
# Tories
# ID
# ID
# ID
# Bar
# ID
# EU
# United
# European
# UK
# Foreign
# Cabinet
# UK
# UK
# European
# Liberal
# BBC
# Financial
# MPs
# NEC
# NEC
# BBC
# MPs
# National
# NEC
# MP
# Quentin
# MP
# Parliamentary
# Nairobi
# Anglican
# House
# Commons
# Candidate
# BNP
# UK
# UKIP
# National
# BNP
# Suffolk
# BNP
# UKIP
# BNP
# BNP
# UKIP
# Liberal
# ILW
# UK
# UK
# Nuclear
# Intermediate
# UK
# Sellafield
# Department
# Commons
# Liberal
# Lib
# Treasury
# DTI
# Energy
# Labour
# UK
# Labour
# MPs
# Labour
# UK
# BBC
# Labour
# Tories
# Shrewsbury
# Election
# QC
# Birmingham
# Midlands
# General
# Election
# Liberal
# Bordesley
# Authority
# BBC
# BBC
# Labour
# Respect
# UK
# UK
# Metropolitan
# MI5
# UK
# Guantanamo
# BBC
# Pentagon
# UK
# US
# Terrorism
# RAF
# Muslim
# Muslim
# Hunting
# BBC
# League
# Hunting
# Bicester
# League
# Bicester
# Lib
# UK
# Tories
# UK
# BBC
# UK
# UK
# Liberal
# Tories
# Nazi
# Nazi
# IOC
# International
# London
# Board
# Standards
# BBC
# Newsnight
# General
# High
# BBC
# Mirror
# Gen
# Gen
# New
# New
# Commander
# Commons
# Liberal
# Immigration
# Nationality
# Conservatives
# Civil
# Treasury
# Department
# Employment
# Work
# Civil
# Inland
# Child
# CSA
# NatWest
# NHS
# GCSEs
# UK
# BBC
# BBC
# BBC
# Muslim
# Cabinet
# Manchester
# BBC
# MEP
# BBC
# Vauxhall
# MEP
# UK
# European
# UKIP
# General
# UKIP
# Commons
# House
# RAC
# Environmental
# People
# Conservatives
# Tory
# Tory
# Liberal
# Conservatives
# Tory
# Tories
# BBC
# Lib
# Tories
# Liberal
# House
# MacDonald
# BBC
# Muslim
# Security
# MacDonald
# Special
# SIAC
# MacDonald
# Radio
# Special
# House
# European
# Tory
# TUC
# TUC
# Health
# TUC
# Hazards
# TUC
# Health
# House
# Lords
# BBC
# European
# Lords
# House
# Lords
# Lords
# Lord
# McConnell
# MSPs
# Scottish
# McConnell
# Scottish
# McConnell
# Make
# Koh
# MPs
# Commons
# BBC
# BBC
# BBC
# News
# World
# BBC
# BBC
# MPs
# MPs
# Environmental
# Defra
# BBC
# Environmental
# Treasury
# MPs
# MPs
# Commons
# MPs
# Committee
# BBC
# Ford
# MPs
# Sentencing
# SGC
# SGC
# Parliament
# Parliament
# Liberal
# MPs
# BBC
# MPs
# Hunting
# Hunting
# Hunting
# League
# Hospital
# BBC
# Powys
# Welsh
# Hereford
# Club2School
# UK
# National
# UK
# Key
# Key
# Tories
# Evangelical
# Bell
# Hansard
# Muslim
# Bell
# Ofsted
# Muslim
# Scottish
# Session
# Barlinnie
# European
# Human
# European
# Human
# Lord
# Scottish
# SNP
# Scottish
# Scottish
# Scottish
# BBC
# Sergeant
# Labour
# NHS
# Gateshead
# GP
# Conservative
# ERM
# Conservative
# Gypsy
# MPs
# Gypsies
# MPs
# Traveller
# MPs
# MPs
# UK
# DNA
# Llyn
# MP
# Merionnydd
# Parliamentary
# BBC
# Lord
# IRA
# Hatfield
# Hatfield
# Countryside
# Appeal
# Hunting
# League
# BBC
# BBC
# Countryside
# Quorn
# BBC
# Countryside
# Hunting
# League
# RSPCA
# Association
# Mental
# Commons
# Catholic
# MPs
# Constitutional
# House
# BBC
# Parliament
# BBC
# PM
# Conservatives
# Waverley
# BBC
# PE
# Conservatives
# Parliament
# UK
# Commons
# House
# Guildford
# BBC
# Belmarsh
# Law
# UK
# House
# Tories
# Lib
# Liberal
# UK
# Former
# Conservative
# Margaret
# IRA
# Maze
# Catholic
# New
# Ulster
# Ulster
# University
# Ulster
# SDLP
# Tory
# Cabinet
# MPs
# Disability
# Conservative
# Parliament
# Lord
# Lord
# Commons
# BBC
# Matrix
# Commons
# Downing
# House
# Conservatives
# Liberal
# Security
# BNP
# National
# Muslim
# Swansea
# BNP
# BNP
# BNP
# BNP
# BNP
# BNP
# UAF
# BNP
# Muslim
# Muslim
# Nazi
# Labour
# Labour
# Culture
# International
# Standards
# UK
# Tories
# Culture
# Rank
# Daily
# Gen
# Mirror
# Directorate
# TimeWarner
# TimeWarner
# Warner
# AOL
# AOL
# AOL
# TimeWarner
# AOL
# TimeWarner
# US
# SEC
# Lord
# TimeWarner
# TimeWarner
# TimeWarner
# AOL
# SEC
# AOL
# AOL
# Federal
# Federal
# US
# Bank
# US
# US
# Yukos
# Menatep
# Menatep
# Reuters
# Rosneft
# US
# BA
# BA
# BA
# Dresdner
# BA
# BA
# BNP
# BA
# BA
# Club
# Financial
# Seagram
# LVMH
# Creek
# WSJ
# Lehman
# US
# Labor
# Labor
# BMO
# ClearView
# G7
# United
# World
# IMF
# G20
# UK
# G7
# IMF
# Food
# Agriculture
# Food
# Agriculture
# FAO
# FAO
# Altria
# RJ
# District
# Reynolds
# Ask
# National
# BBC
# Mitsubishi
# SUV
# Mitsubishi
# SUVs
# Mitsubishi
# Mitsubishi
# DaimlerChrylser
# Mitsubishi
# Mitsubishi
# Nissan
# Telegraph
# Daily
# Telegraph
# National
# National
# Journalists
# NUJ
# NUJ
# Telegraph
# Telegraph
# Telegraph
# Barclay
# Hollinger
# Daily
# News
# News
# Sun
# News
# Guardian
# Daily
# General
# European
# European
# ELAA
# International
# IATA
# Radio
# European
# ERAA
# ERAA
# EC
# ERAA
# European
# Commissioner
# Transport
# Union
# EC
# Parmalat
# Parmalat
# UBS
# FDI
# Investment
# Sterling
# Tata
# Sunovate
# Dimension
# Leisure
# Rank
# Goldman
# Pinewood
# Hard
# DVDs
# DVDs
# VHS
# UK
# Mecca
# Federal
# Chancellor
# Hypovereinsbank
# GDP
# European
# Deutsche
# New
# Commerce
# Bush
# IXIS
# Yukos
# US
# US
# European
# Human
# US
# US
# Deutsche
# Gazprom
# GM
# General
# National
# NHTSA
# SUVs
# GM
# Chevrolet
# GMC
# NHTSA
# SRX
# GMC
# GM
# GM
# US
# GM
# Mittal
# ISG
# US
# International
# LNM
# Mittal
# ISG
# Mittal
# Czech
# International
# IEA
# IEA
# IEA
# US
# Energy
# Yukos
# IEA
# Venezuelan
# Vestey
# Vestey
# Reuters
# Reuters
# Century
# Venezuelan
# Vestey
# Venezuelan
# OECD
# OECD
# OECD
# OECD
# OECD
# OECD
# OECD
# OECD
# BBC
# OECD
# OECD
# ISEQ
# Bank
# Reuters
# NCB
# Reuters
# Sumitomo
# UFJ
# UFJ
# UFJ
# UFJ
# UFJ
# Mitsubishi
# MTFG
# UFJ
# UFJ
# MTFG
# UFJ
# UFJ
# Daiwa
# MG
# Financial
# UK
# FT
# BBC
# UK
# General
# Birmingham
# SAIC
# FT
# SAIC
# BBC
# SAIC
# WPP
# WPP
# WPP
# Grey
# Reuters
# WPP
# NOP
# Ogilvy
# Cordiant
# WPP
# US
# FIFA
# WPP
# US
# US
# Securities
# Exchange
# SEC
# Worldcom
# Sox
# SEC
# Washington
# UK
# CBI
# US
# CBI
# SEC
# SEC
# CBI
# BBC
# SEC
# European
# SEC
# Mitsubishi
# UFJ
# OAO
# USA
# Dresdner
# Shenzhen
# Yantai
# US
# Yantai
# US
# US
# Rangers
# UK
# London
# UK
# Federal
# House
# Congress
# Congress
# Congress
# US
# UK
# UK
# UK
# Ministry
# Foreign
# Cabinet
# GDP
# GDP
# US
# Reuters
# Energy
# US
# BP
# Ministry
# METI
# UFJ
# METI
# Nikkei
# Parmalat
# Parmalat
# Parmalat
# Parmalat
# Parmalat
# BMW
# Oxford
# BMW
# Mini
# BMW
# BMW
# BMW
# Automotive
# Cooper
# Mini
# Mini
# Mini
# Mercedes
# BMW
# BMW
# Mini
# UK
# Phoenix
# BMW
# Oxford
# Mini
# MG
# SAIC
# Longbridge
# MG
# BMW
# Nestle
# Americas
# Financial
# GM
# Formula
# Mediobanca
# Maserati
# Financial
# General
# Development
# R
# Enel
# Reuters
# Reuters
# Canary
# Hyundai
# BMW
# BMW
# Rolls-Royce
# BMW
# BMW
# BMW
# BMW
# BMW
# BMW
# UK
# Bank
# National
# ONS
# ONS
# BoE
# Bank
# ONS
# ONS
# MPC
# Bank
# Monetary
# MPC
# Bank
# ONS
# House
# Lords
# MPC
# MPC
# MPC
# Newton
# AEG
# Frigidaire
# Worldcom
# WorldCom
# WorldCom
# US
# WorldCom
# WorldCom
# WorldCom
# WorldCom
# WorldCom
# WorldCom
# MCI
# MCI
# Verizon
# American
# International
# AIG
# McLennan
# UK
# National
# ONS
# UK
# Bank
# Monument
# Reuters
# BoE
# Multiplex
# Wembley
# Wembley
# Goldman
# Reuters
# US
# US
# SG
# Investment
# Nomura
# Popular
# BBC
# Frankfurt
# European
# EU
# SARS
# Association
# EU
# Ifo
# DZ
# DaimlerChrysler
# Volkswagen
# Ifo
# European
# FAO
# UN
# Food
# Agriculture
# FAO
# Agricultural
# FAO
# FAO
# World
# European
# FAO
# Commerce
# DLF
# BBC
# Foreign
# CB
# BBC
# Centre
# CITU
# FDI
# Boeing
# Boeing
# GE
# Boeing
# International
# EVA
# Highfields
# CL
# Sapporo
# LG
# Federal
# Volkswagen
# DaimlerChrysler
# European
# ECB
# MPs
# MPs
# Turkcell
# MTN
# TAV
# European
# EU
# G7
# World
# Intifada
# World
# US
# VEB
# CNPC
# CNPC
# VEB
# CNPC
# US
# CNPC
# General
# Fiat
# GM
# GM
# DaimlerChrysler
# Fiat
# GM
# GM
# GM
# Sal
# Federal
# ID
# ID
# PCs
# PDVSA
# BMW
# BMW
# BMW
# BMW
# Mercedes
# DaimlerChrysler
# Mercedes
# Mercedes
# City
# United
# UPS
# GE
# Mothercare
# UPS
# Deutsche
# US
# US
# US
# Yukos
# Gazprom
# US
# US
# US
# Bank
# GDP
# Bank
# Bank
# US
# Inter-American
# Inter-American
# UK
# Bank
# Bankers
# BoE
# BBA
# Bank
# Chartered
# CIPS
# PMI
# PMI
# CIPS
# CIPS
# UK
# Bank
# Worldcom
# Former
# Worldcom
# Worldcom
# Worldcom
# Worldcom
# Worldcom
# CEO
# Metlife
# Citigroup
# Citigroup
# Travelers
# Metlife
# Citigroup
# Metlife
# US
# Metlife
# Metlife
# Citibank
# Metlife
# Gartmore
# US
# US
# JPMorgan
# US
# European
# FNSEA
# Associated
# Yukos
# MPs
# MPs
# Turkcell
# Parliament
# TAV
# UK
# Luxembourg
# GDP
# GDP
# Commerce
# R
# US
# Republic
# US
# US
# US
# US
# Commerzbank
# US
# IMF
# International
# Financial
# IMF
# IMF
# FT
# IMF
# IMF
# Organisation
# Economic
# Development
# ABN
# General
# GM
# Ford
# Ford
# SUVs
# Pontiac
# GM
# GM
# Ford
# US
# DaimlerChrysler
# US
# WorldCom
# WorldCom
# WorldCom
# WorldCom
# WorldCom
# MCI
# Reserve
# Bank
# Bank
# GDP
# Bank
# Reserve
# Bank
# Commonwealth
# US
# Securities
# Exchange
# SEC
# SEC
# US
# McLennan
# MMC
# MMC
# Trident
# US
# US
# US
# District
# Altria
# RJ
# Philip
# BBC
# Fiat
# General
# GM
# GM
# GM
# Reuters
# Reuters
# Fiat
# GTV
# GT
# General
# Cadillac
# GM
# Saab
# GM
# GM
# BMW
# Mercedes
# Toyota
# US
# Mercedes
# BMW
# Saab
# GM
# UK
# BBC
# GM
# Vauxhall
# GM
# Vauxhall
# Number of ORGANIZATION: 1543

# %%
# Number of GPE/locations
num_gpe = 0
for n in chunked_corpus:
    if isinstance(n, nltk.tree.Tree):
        if n.label() == 'GPE':
            num_gpe += 1

print('Number of GPE:', num_gpe)
# Out:
# Number of GPE: 1432

# %% [markdown]
# ### Now we will study N-grams
# See example below, fill in the missing code.
#
# 11) Are there any bigrams or trigram or ngrams that give
# logical groups of texts/grams?

# %%
import nltk
from nltk import bigrams,trigrams
sent = ("Israeli Prime Minister Ehud Olmert is scheduled to meet with Palestinian President Mahmoud Abbas Wednesday in Jerusalem. Palestinian negotiator Saeb Erekat said the talks will focus on permanent- status issues, Israeli checkpoints and the fate of Palestinian prisoners. The meeting, at Mr. Olmert's official residence, will be the first between the two since Mr. Olmert announced that he will step down after his Kadima Party chooses a new leader in September. The two leaders re-started peace talks in November with the goal of reaching a deal by this year's end")
tokenised = nltk.word_tokenize(sent)
grams = trigrams(tokenised)

# %%
bigrams_list = list(bigrams(tokenised))
print('Bigrams:')
print(bigrams_list)


trigrams_list = list(trigrams(tokenised))
print('\nTrigrams:')
print(trigrams_list)
# Out:
# Bigrams:
# [('Israeli', 'Prime'), ('Prime', 'Minister'), ('Minister', 'Ehud'), ('Ehud', 'Olmert'), ('Olmert', 'is'), ('is', 'scheduled'), ('scheduled', 'to'), ('to', 'meet'), ('meet', 'with'), ('with', 'Palestinian'), ('Palestinian', 'President'), ('President', 'Mahmoud'), ('Mahmoud', 'Abbas'), ('Abbas', 'Wednesday'), ('Wednesday', 'in'), ('in', 'Jerusalem'), ('Jerusalem', '.'), ('.', 'Palestinian'), ('Palestinian', 'negotiator'), ('negotiator', 'Saeb'), ('Saeb', 'Erekat'), ('Erekat', 'said'), ('said', 'the'), ('the', 'talks'), ('talks', 'will'), ('will', 'focus'), ('focus', 'on'), ('on', 'permanent-'), ('permanent-', 'status'), ('status', 'issues'), ('issues', ','), (',', 'Israeli'), ('Israeli', 'checkpoints'), ('checkpoints', 'and'), ('and', 'the'), ('the', 'fate'), ('fate', 'of'), ('of', 'Palestinian'), ('Palestinian', 'prisoners'), ('prisoners', '.'), ('.', 'The'), ('The', 'meeting'), ('meeting', ','), (',', 'at'), ('at', 'Mr.'), ('Mr.', 'Olmert'), ('Olmert', "'s"), ("'s", 'official'), ('official', 'residence'), ('residence', ','), (',', 'will'), ('will', 'be'), ('be', 'the'), ('the', 'first'), ('first', 'between'), ('between', 'the'), ('the', 'two'), ('two', 'since'), ('since', 'Mr.'), ('Mr.', 'Olmert'), ('Olmert', 'announced'), ('announced', 'that'), ('that', 'he'), ('he', 'will'), ('will', 'step'), ('step', 'down'), ('down', 'after'), ('after', 'his'), ('his', 'Kadima'), ('Kadima', 'Party'), ('Party', 'chooses'), ('chooses', 'a'), ('a', 'new'), ('new', 'leader'), ('leader', 'in'), ('in', 'September'), ('September', '.'), ('.', 'The'), ('The', 'two'), ('two', 'leaders'), ('leaders', 're-started'), ('re-started', 'peace'), ('peace', 'talks'), ('talks', 'in'), ('in', 'November'), ('November', 'with'), ('with', 'the'), ('the', 'goal'), ('goal', 'of'), ('of', 'reaching'), ('reaching', 'a'), ('a', 'deal'), ('deal', 'by'), ('by', 'this'), ('this', 'year'), ('year', "'s"), ("'s", 'end')]
#
# Trigrams:
# [('Israeli', 'Prime', 'Minister'), ('Prime', 'Minister', 'Ehud'), ('Minister', 'Ehud', 'Olmert'), ('Ehud', 'Olmert', 'is'), ('Olmert', 'is', 'scheduled'), ('is', 'scheduled', 'to'), ('scheduled', 'to', 'meet'), ('to', 'meet', 'with'), ('meet', 'with', 'Palestinian'), ('with', 'Palestinian', 'President'), ('Palestinian', 'President', 'Mahmoud'), ('President', 'Mahmoud', 'Abbas'), ('Mahmoud', 'Abbas', 'Wednesday'), ('Abbas', 'Wednesday', 'in'), ('Wednesday', 'in', 'Jerusalem'), ('in', 'Jerusalem', '.'), ('Jerusalem', '.', 'Palestinian'), ('.', 'Palestinian', 'negotiator'), ('Palestinian', 'negotiator', 'Saeb'), ('negotiator', 'Saeb', 'Erekat'), ('Saeb', 'Erekat', 'said'), ('Erekat', 'said', 'the'), ('said', 'the', 'talks'), ('the', 'talks', 'will'), ('talks', 'will', 'focus'), ('will', 'focus', 'on'), ('focus', 'on', 'permanent-'), ('on', 'permanent-', 'status'), ('permanent-', 'status', 'issues'), ('status', 'issues', ','), ('issues', ',', 'Israeli'), (',', 'Israeli', 'checkpoints'), ('Israeli', 'checkpoints', 'and'), ('checkpoints', 'and', 'the'), ('and', 'the', 'fate'), ('the', 'fate', 'of'), ('fate', 'of', 'Palestinian'), ('of', 'Palestinian', 'prisoners'), ('Palestinian', 'prisoners', '.'), ('prisoners', '.', 'The'), ('.', 'The', 'meeting'), ('The', 'meeting', ','), ('meeting', ',', 'at'), (',', 'at', 'Mr.'), ('at', 'Mr.', 'Olmert'), ('Mr.', 'Olmert', "'s"), ('Olmert', "'s", 'official'), ("'s", 'official', 'residence'), ('official', 'residence', ','), ('residence', ',', 'will'), (',', 'will', 'be'), ('will', 'be', 'the'), ('be', 'the', 'first'), ('the', 'first', 'between'), ('first', 'between', 'the'), ('between', 'the', 'two'), ('the', 'two', 'since'), ('two', 'since', 'Mr.'), ('since', 'Mr.', 'Olmert'), ('Mr.', 'Olmert', 'announced'), ('Olmert', 'announced', 'that'), ('announced', 'that', 'he'), ('that', 'he', 'will'), ('he', 'will', 'step'), ('will', 'step', 'down'), ('step', 'down', 'after'), ('down', 'after', 'his'), ('after', 'his', 'Kadima'), ('his', 'Kadima', 'Party'), ('Kadima', 'Party', 'chooses'), ('Party', 'chooses', 'a'), ('chooses', 'a', 'new'), ('a', 'new', 'leader'), ('new', 'leader', 'in'), ('leader', 'in', 'September'), ('in', 'September', '.'), ('September', '.', 'The'), ('.', 'The', 'two'), ('The', 'two', 'leaders'), ('two', 'leaders', 're-started'), ('leaders', 're-started', 'peace'), ('re-started', 'peace', 'talks'), ('peace', 'talks', 'in'), ('talks', 'in', 'November'), ('in', 'November', 'with'), ('November', 'with', 'the'), ('with', 'the', 'goal'), ('the', 'goal', 'of'), ('goal', 'of', 'reaching'), ('of', 'reaching', 'a'), ('reaching', 'a', 'deal'), ('a', 'deal', 'by'), ('deal', 'by', 'this'), ('by', 'this', 'year'), ('this', 'year', "'s"), ('year', "'s", 'end')]

# %% [markdown]
# ### Now we will do some regular expression matching

# %%
# Import regular expression library for Python
import re

# Match all Sweden in the corpusText
re.findall(r"Sweden", corpusText)
# Out:
# ['Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Sweden']

# %% [markdown]
# Do the same for Sweden again but extract also the snippet/text around them.
#
# 12) What do you see?

# %%
re.findall(".{0,20}Sweden.{0,20}", corpusText) # they have to be in the same parragraph
# Out:
# ['the UK third behind Sweden and Ireland for bus',
#  'ly, Switzerland and Sweden will be stored perm',
#  'l sides of Ireland, Sweden and Norway. Shares ',
#  'end up producing in Sweden?"',
#  ' build Cadillacs in Sweden',
#  'ing Saab factory in Sweden.',
#  'lloyed good news in Sweden, since it reflects ',
#  ' American marque in Sweden is part of its effo',
#  'illac production to Sweden should help introdu']

# %% [markdown]
# Do the same for the car company SAAB but extract also the snippet/text around them.
#
# 13) What do you see?

# %%
saab_matches = re.findall(r"Saab", corpusText)
print('\n "SAAB":', saab_matches)


saab_context_matches = re.findall(r".{0,20}Saab.{0,20}", corpusText)
print('\nContext for "Saab":', saab_context_matches)
# Out:
#  "SAAB": ['Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab', 'Saab']
#
# Context for "Saab": ['pean units Opel and Saab have both had troub', 'Saab to build Cadillacs ', ' at its loss-making Saab factory in Sweden.', " allay fears of the Saab factory's closure. ", ", since it reflects Saab's failure to make s", ' market. For years, Saab has consistently sa', 'needed scale to the Saab factory, which curr', 'ble operations, and Saab is losing money fas', 'nditure by building Saabs, Opels - badged as', "y to further reduce Saab's losses could be t", 'f the production of Saabs to the US, a marke', 'ar, which is making Saabs more expensive to ']

# %% [markdown]
# Combine the two regular expressions so get both Sweden and Saab in the same context.
#
# 14) Are the results comprehensible? How can you improve them?

# %%
combined_matches = re.findall(r".{0,10}Sweden.*Saab.{0,10}", corpusText)
print('\nCombined Matches:', combined_matches)
# Out:
# Combined Matches: ["d news in Sweden, since it reflects Saab's failure to make significant inroads into the lucrative European luxury car market. For years, Saab has consi", "uction to Sweden should help introduce desperately-needed scale to the Saab factory, which currently produces fewer than 130,000 cars per year. That is about half of what major car makers consider sufficient numbers for profitable operations, and Saab is losing money fast - albeit with losses halved in 2004 to $200m (£104m; 151m euros) from $500m the previous year. Beyond the 12,000 job cuts announced last year at its European operations, GM is reducing expenditure by building Saabs, Opels - badged as Vauxhalls in the UK - and now Cadillacs on the same framework, and by allowing the different brands to share parts. Another way to further reduce Saab's losses could be to shift some of the production of Saabs to the US, a market where drivers have adopted it as an upmarket European car. Doing so would remove the exposure to the weak US dollar, which is making Saabs more exp"]

# %%
combined_matches = re.findall(r".{0,20}Saab.*Sweden.{0,20}", corpusText)
print('\nCombined Matches:', combined_matches)
# Out:
# Combined Matches: ['Saab to build Cadillacs in Sweden', ' at its loss-making Saab factory in Sweden.']

# %% [markdown]
# ### Here is an extra task which is not compulsary.
# Match all organisations that is close to Sweden in the BBC corpus and print the snippets.
#
# 15) What do you get? Are there repetitions? How can one avoid them?

# %%
combined_matches = re.findall(r".{0,20}Sweden.*.{0,20}", corpusText)
print('\nCombined Matches:', combined_matches)
# Out:
# Combined Matches: ['the UK third behind Sweden and Ireland for business use of ICT.', 'ly, Switzerland and Sweden will be stored permanently in the UK. At the moment, this waste is stored at Sellafield, in Cumbria, in the form of glass bricks, untreated liquid waste or solid material in drums. In a statement, the Department of Trade and Industry said the new policy meant there would be a "sixfold reduction in the number of waste shipments to overseas countries". And it said highly-radioactive waste would be returned to its home country sooner, ensuring there would be no overall increase in radioactivity.', 'l sides of Ireland, Sweden and Norway. Shares in Umbro were up 1.76% at 115.5 pence in morning trade.', 'end up producing in Sweden?"', ' build Cadillacs in Sweden', 'ing Saab factory in Sweden.', "lloyed good news in Sweden, since it reflects Saab's failure to make significant inroads into the lucrative European luxury car market. For years, Saab has consistently said it is competing head-on with BMW, Mercedes and Jaguar. The segment's leaders do not agree.", ' American marque in Sweden is part of its efforts to push it as an alternative luxury brand for European drivers. In the US, it has long been established as an upmarket brand - even the presidential limousine carries the badge. Yet it could prove tough for Cadillac to steal market share from the majors in Europe. Other luxury car makers, most notably the Toyota subsidiary Lexus, have enjoyed tremendous success in the US without managing to make significant inroads in Europe. There, German marques Mercedes Benz and BMW have retained their stranglehold on the luxury market.', 'illac production to Sweden should help introduce desperately-needed scale to the Saab factory, which currently produces fewer than 130,000 cars per year. That is about half of what major car makers consider sufficient numbers for profitable operations, and Saab is losing money fast - albeit with losses halved in 2004 to $200m (£104m; 151m euros) from $500m the previous year. Beyond the 12,000 job cuts announced last year at its European operations, GM is reducing expenditure by building Saabs, Opels - badged as Vauxhalls in the UK - and now Cadillacs on the same framework, and by allowing the different brands to share parts. Another way to further reduce Saab\'s losses could be to shift some of the production of Saabs to the US, a market where drivers have adopted it as an upmarket European car. Doing so would remove the exposure to the weak US dollar, which is making Saabs more expensive to US consumers. But not everyone in the industry agree that it would be the best way forward. "We know that in five years the US dollar will be stronger than it is today," the chief executive of a leading European car maker told BBC News. The current trend towards US production was "stupid", he said.']

# %%
# Number of ORGANIZATION
num_organizations = 0
org= []
for n in chunked_corpus:
    if isinstance(n, nltk.tree.Tree):
        if n.label() == 'ORGANIZATION':
            print(n.leaves())
            print(n.leaves()[0][0])
            org.append(n.leaves()[0][0])
org = set(org)
print((org))
# Out:
# [('CSOs', 'NNP')]
# CSOs
# [('CSOs', 'NNP')]
# CSOs
# [('CSOs', 'NNP')]
# CSOs
# [('UK', 'NNP')]
# UK
# [('Czech', 'NNP'), ('Republic', 'NNP')]
# Czech
# [('Islamic', 'JJ')]
# Islamic
# [('McConnell', 'NNP')]
# McConnell
# [('SNP', 'NNP')]
# SNP
# [('Scottish', 'NNP')]
# Scottish
# [('McConnell', 'NNP')]
# McConnell
# [('Loch', 'NNP'), ('Ness', 'NNP'), ('West', 'NNP')]
# Loch
# [('Highlands', 'NNP')]
# Highlands
# [('SNP', 'NNP'), ('Holyrood', 'NNP')]
# SNP
# [('McConnell', 'NNP')]
# McConnell
# [('First', 'NNP'), ('Division', 'NNP'), ('Association', 'NNP')]
# First
# [('BBC', 'NNP')]
# BBC
# [('Chancellor', 'NNP')]
# Chancellor
# [('BBC', 'NNP')]
# BBC
# [('Treasury', 'NNP')]
# Treasury
# [('Treasury', 'NNP')]
# Treasury
# [('Treasury', 'NNP')]
# Treasury
# [('Conservative', 'NNP'), ('Party', 'NNP')]
# Conservative
# [('MPs', 'NNP')]
# MPs
# [('Welsh', 'NNP'), ('Assembly', 'NNP')]
# Welsh
# [('Conservatives', 'NNPS')]
# Conservatives
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('Whitehall', 'NNP')]
# Whitehall
# [('Parliament', 'NNP')]
# Parliament
# [('Commons', 'NNP'), ('Oliver', 'NNP'), ('Heald', 'NNP')]
# Commons
# [('Westminster', 'NNP')]
# Westminster
# [('United', 'NNP'), ('Kingdom', 'NNP')]
# United
# [('House', 'NNP')]
# House
# [('UK', 'NNP')]
# UK
# [('Belmarsh', 'NNP')]
# Belmarsh
# [('Foreign', 'NNP')]
# Foreign
# [('Law', 'NNP'), ('Lords', 'NNP')]
# Law
# [('Liberal', 'NNP'), ('Democrat', 'NNP')]
# Liberal
# [('Belmarsh', 'NNP')]
# Belmarsh
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('BBC', 'NNP')]
# BBC
# [('Fraser', 'NNP')]
# Fraser
# [('Allander', 'NNP'), ('Institute', 'NNP')]
# Allander
# [('SNP', 'NNP'), ('Holyrood', 'NNP')]
# SNP
# [('Scottish', 'JJ')]
# Scottish
# [('Quarterly', 'JJ'), ('Economic', 'NNP')]
# Quarterly
# [('Strathclyde', 'NNP'), ('University', 'NNP')]
# Strathclyde
# [('Allander', 'NNP'), ('Institute', 'NNP')]
# Allander
# [('BBC', 'NNP'), ('Radio', 'NNP')]
# BBC
# [('Scottish', 'NNP'), ('National', 'NNP'), ('Party', 'NNP')]
# Scottish
# [('Scottish', 'JJ'), ('Executive', 'NNP')]
# Scottish
# [('Labour', 'NNP')]
# Labour
# [('Liberal', 'JJ'), ('Democrats', 'NNPS')]
# Liberal
# [('MI6', 'NNP')]
# MI6
# [('MI6', 'NNP')]
# MI6
# [('UK', 'NNP')]
# UK
# [('MI6', 'NNP')]
# MI6
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('Foreign', 'NNP')]
# Foreign
# [('BBC', 'NNP'), ('One', 'NNP')]
# BBC
# [('Muslim', 'NNP')]
# Muslim
# [('Department', 'NNP')]
# Department
# [('Defense', 'NNP')]
# Defense
# [('US', 'NNP')]
# US
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP'), ('Treasury', 'NNP')]
# UK
# [('Welsh', 'NNP'), ('Local', 'NNP')]
# Welsh
# [('WLGA', 'NNP')]
# WLGA
# [('WLGA', 'NNP')]
# WLGA
# [('Labour', 'NNP'), ('Assembly', 'NNP')]
# Labour
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('Tories', 'NNPS')]
# Tories
# [('Lib', 'NNP'), ('Dems', 'NNPS')]
# Lib
# [('UK', 'NNP')]
# UK
# [('BBC', 'NNP')]
# BBC
# [('BBC', 'NNP')]
# BBC
# [('UK', 'NNP')]
# UK
# [('Children', 'NNP'), ('Bill', 'NNP')]
# Children
# [('Commons', 'NNP')]
# Commons
# [('Association', 'NNP'), ('of', 'IN'), ('Directors', 'NNPS')]
# Association
# [('Social', 'NNP'), ('Services', 'NNPS')]
# Social
# [('ADSS', 'NNP')]
# ADSS
# [('ADSS', 'NNP')]
# ADSS
# [('HRH', 'NNP'), ('Duchess', 'NNP')]
# HRH
# [('Cornwall', 'NNP')]
# Cornwall
# [('Windsor', 'NNP'), ('Castle', 'NNP')]
# Windsor
# [('Daily', 'JJ'), ('Telegraph', 'NNP')]
# Daily
# [('Princess', 'NNP'), ('Consort', 'NNP')]
# Princess
# [('Windsor', 'NNP'), ('Castle', 'NNP')]
# Windsor
# [('Royal', 'NNP'), ('Family', 'NNP')]
# Royal
# [('Queen', 'NNP')]
# Queen
# [('Duke', 'NNP')]
# Duke
# [('Archbishop', 'NNP')]
# Archbishop
# [('Church', 'NNP')]
# Church
# [('Archbishop', 'NNP')]
# Archbishop
# [('Liberal', 'NNP')]
# Liberal
# [('Islamic', 'NNP')]
# Islamic
# [('Islamic', 'NNP')]
# Islamic
# [('UK', 'NNP')]
# UK
# [('Commons', 'NNP')]
# Commons
# [('Islamic', 'NNP')]
# Islamic
# [('IHRC', 'NNP')]
# IHRC
# [('Salford', 'NNP')]
# Salford
# [('Commons', 'NNP')]
# Commons
# [('Muslim', 'NNP')]
# Muslim
# [('IHRC', 'NNP')]
# IHRC
# [('UK', 'NNP')]
# UK
# [('Terrorism', 'NNP')]
# Terrorism
# [('Muslim', 'NNP')]
# Muslim
# [('Muslim', 'NNP')]
# Muslim
# [('Tory', 'NNP')]
# Tory
# [('Refugee', 'NNP'), ('Council', 'NNP')]
# Refugee
# [('UK', 'NNP')]
# UK
# [('Tory', 'NNP')]
# Tory
# [('Liberal', 'NNP')]
# Liberal
# [('Conservatives', 'NNPS')]
# Conservatives
# [('NHS', 'NNP')]
# NHS
# [('New', 'NNP'), ('Labour', 'NNP')]
# New
# [('BBC', 'NNP')]
# BBC
# [('BBC', 'NNP')]
# BBC
# [('Tory', 'NNP')]
# Tory
# [('Transport', 'NNP')]
# Transport
# [('General', 'NNP'), ('Workers', 'NNP'), ('Union', 'NNP')]
# General
# [('TGWU', 'NNP')]
# TGWU
# [('TGWU', 'NNP')]
# TGWU
# [('GMB', 'NNP')]
# GMB
# [('TGWU', 'NNP')]
# TGWU
# [('Warwick', 'NNP'), ('Agreement', 'NNP')]
# Warwick
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('TGWU', 'NNP')]
# TGWU
# [('UK', 'NNP')]
# UK
# [('ICT', 'NNP')]
# ICT
# [('UK', 'JJ')]
# UK
# [('HI', 'NNP'), ('Europe', 'NNP')]
# HI
# [('UK', 'NNP')]
# UK
# [('ICT', 'NNP')]
# ICT
# [('ICT', 'NNP')]
# ICT
# [('ICT', 'NNP')]
# ICT
# [('UK', 'NNP')]
# UK
# [('ICT', 'NNP')]
# ICT
# [('ICT', 'NNP')]
# ICT
# [('UK', 'NNP')]
# UK
# [('International', 'NNP'), ('Benchmarking', 'NNP'), ('Study', 'NNP')]
# International
# [('ICT', 'NNP')]
# ICT
# [('Conservative', 'JJ')]
# Conservative
# [('Tories', 'NNPS')]
# Tories
# [('UK', 'NNP'), ('Independence', 'NNP'), ('Party', 'NNP')]
# UK
# [('Veritas', 'NNP')]
# Veritas
# [('UKIP', 'NNP')]
# UKIP
# [('Defence', 'NNP')]
# Defence
# [('Ashfield', 'NNP')]
# Ashfield
# [('UKIP', 'NNP')]
# UKIP
# [('London', 'NNP'), ('Assembly', 'NNPS')]
# London
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('Leicestershire', 'NNP')]
# Leicestershire
# [('UKIP', 'NNP')]
# UKIP
# [('AWOL', 'NNP')]
# AWOL
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('London', 'NNP'), ('Assembly', 'NNP')]
# London
# [('UK', 'NNP'), ('Independence', 'NNP'), ('Party', 'NNP')]
# UK
# [('UKIP', 'NNP')]
# UKIP
# [('Eurosceptic', 'NNP')]
# Eurosceptic
# [('UKIP', 'NNP')]
# UKIP
# [('UK', 'NNP')]
# UK
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('English', 'JJ'), ('Democrats', 'NNPS')]
# English
# [('New', 'NNP'), ('Party', 'NNP')]
# New
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('RKS', 'NNP')]
# RKS
# [('Veritas', 'NNP')]
# Veritas
# [('YouGov', 'NNP')]
# YouGov
# [('Cabinet', 'NNP')]
# Cabinet
# [('Blunkett', 'NNP')]
# Blunkett
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('CommunicateResearch', 'NNP')]
# CommunicateResearch
# [('Euston', 'NNP'), ('Road', 'NNP')]
# Euston
# [('Green', 'NNP'), ('Party', 'NNP')]
# Green
# [('University', 'NNP'), ('College', 'NNP'), ('London', 'NNP')]
# University
# [('Parliamentary', 'NNP'), ('Advisory', 'NNP'), ('Council', 'NNP')]
# Parliamentary
# [('Transport', 'NNP'), ('Safety', 'NNP')]
# Transport
# [('MPs', 'NNP')]
# MPs
# [('UK', 'NNP')]
# UK
# [('Transport', 'NNP'), ('Document', 'NNP')]
# Transport
# [('BAC', 'NNP')]
# BAC
# [('AA', 'NNP')]
# AA
# [('Liberal', 'NNP')]
# Liberal
# [('Road', 'NNP'), ('Safety', 'NNP'), ('Bill', 'NNP')]
# Road
# [('Labour', 'NNP')]
# Labour
# [('Times', 'NNP')]
# Times
# [('Transport', 'NNP'), ('Select', 'NNP'), ('Committee', 'NNP')]
# Transport
# [('CSA', 'NNP')]
# CSA
# [('Child', 'NNP'), ('Support', 'NNP'), ('Agency', 'NNP')]
# Child
# [('CSA', 'NNP')]
# CSA
# [('Commons', 'NNP')]
# Commons
# [('CSA', 'NNP')]
# CSA
# [('CSA', 'NNP')]
# CSA
# [('Parliament', 'NNP')]
# Parliament
# [('CS2', 'NNP')]
# CS2
# [('BBC', 'NNP')]
# BBC
# [('MPs', 'NNP')]
# MPs
# [('CSA', 'NNP')]
# CSA
# [('MPs', 'NNP')]
# MPs
# [('EDS', 'NNP')]
# EDS
# [('CSA', 'NNP')]
# CSA
# [('CSA', 'NNP')]
# CSA
# [('National', 'NNP'), ('Audit', 'NNP')]
# National
# [('EDS', 'NNP')]
# EDS
# [('House', 'NNP')]
# House
# [('Lords', 'NNPS')]
# Lords
# [('Commons', 'NNP'), ('Speaker', 'NNP')]
# Commons
# [('BBC', 'NNP')]
# BBC
# [('Lords', 'NNP')]
# Lords
# [('Lords', 'NNP')]
# Lords
# [('Commons', 'NNPS')]
# Commons
# [('BBC1', 'NNP')]
# BBC1
# [('Commons', 'NNPS')]
# Commons
# [('House', 'NNP')]
# House
# [('Cabinet', 'NNP')]
# Cabinet
# [('House', 'NNP')]
# House
# [('House', 'NNP')]
# House
# [('Department', 'NNP')]
# Department
# [('Constitutional', 'NNP'), ('Affairs', 'NNPS')]
# Constitutional
# [('BBC', 'NNP')]
# BBC
# [('House', 'NNP')]
# House
# [('Parliament', 'NNP')]
# Parliament
# [('House', 'NNP')]
# House
# [('House', 'NNP')]
# House
# [('Parliament', 'NNP')]
# Parliament
# [('Law', 'NNP'), ('Commission', 'NNP')]
# Law
# [('Lord', 'NNP')]
# Lord
# [('Lords', 'NNP')]
# Lords
# [('Lord', 'NNP')]
# Lord
# [('Human', 'NNP'), ('Rights', 'NNP')]
# Human
# [('Family', 'NNP')]
# Family
# [('Merseyside', 'NNP')]
# Merseyside
# [('Commission', 'NNP')]
# Commission
# [('Nazi', 'JJ')]
# Nazi
# [('Prince', 'NNP'), ('Harry', 'NNP')]
# Prince
# [('Prince', 'NNP'), ('William', 'NNP')]
# Prince
# [('ITV', 'NNP')]
# ITV
# [('Nazis', 'NNP')]
# Nazis
# [('Nazis', 'NNP')]
# Nazis
# [('Sun', 'NNP')]
# Sun
# [('Nazi', 'NNP')]
# Nazi
# [('BBC', 'NNP')]
# BBC
# [('Buckingham', 'NNP'), ('Palace', 'NNP')]
# Buckingham
# [('Hospital', 'NNP')]
# Hospital
# [('New', 'NNP'), ('Year', 'NNP')]
# New
# [('BMA', 'NNP')]
# BMA
# [('Welsh', 'NNP'), ('Institute', 'NNP')]
# Welsh
# [('Social', 'NNP'), ('Care', 'NNP')]
# Social
# [('Welsh', 'NNP'), ('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Welsh
# [('Audit', 'NNP'), ('Commission', 'NNP')]
# Audit
# [('UK', 'NNP')]
# UK
# [('Tuberculosis', 'NNP')]
# Tuberculosis
# [('HIV', 'NNP')]
# HIV
# [('Conservatives', 'NNPS')]
# Conservatives
# [('TB', 'NNP')]
# TB
# [('HIV', 'NNP')]
# HIV
# [('NHS', 'NNP')]
# NHS
# [('Lib', 'NNP'), ('Dems', 'NNP')]
# Lib
# [('Conservatives', 'NNPS')]
# Conservatives
# [('General', 'NNP'), ('Election', 'NNP')]
# General
# [('UK', 'NNP')]
# UK
# [('BBC', 'NNP')]
# BBC
# [('UK', 'NNP')]
# UK
# [('NHS', 'NNP')]
# NHS
# [('TB', 'NNP')]
# TB
# [('HIV', 'NNP')]
# HIV
# [('TB', 'NNP')]
# TB
# [('Heathrow', 'NNP')]
# Heathrow
# [('Lung', 'NNP'), ('Foundation', 'NNP')]
# Lung
# [('UK', 'NNP')]
# UK
# [('Liberal', 'NNP')]
# Liberal
# [('Labour', 'NNP')]
# Labour
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Aids', 'NNP')]
# Aids
# [('Terrence', 'NNP'), ('Higgins', 'NNP'), ('Trust', 'NNP')]
# Terrence
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('Commons', 'NNPS')]
# Commons
# [('MPs', 'NNP')]
# MPs
# [('Commons', 'NNP')]
# Commons
# [('Commons', 'NNP')]
# Commons
# [('House', 'NNP')]
# House
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('AM', 'NNP')]
# AM
# [('NHS', 'NNP')]
# NHS
# [('NHS', 'NNP')]
# NHS
# [('NHS', 'NNP')]
# NHS
# [('NHS', 'NNP')]
# NHS
# [('BBC', 'NNP')]
# BBC
# [('NHS', 'NNP')]
# NHS
# [('NHS', 'NNP')]
# NHS
# [('Plaid', 'NNP'), ('Cymru', 'NNP')]
# Plaid
# [('Lib', 'NNP'), ('Dems', 'NNP')]
# Lib
# [('MPs', 'NNP')]
# MPs
# [('Welsh', 'NNP'), ('Assembly', 'NNP')]
# Welsh
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('UKIP', 'NNP')]
# UKIP
# [('MEP', 'NNP')]
# MEP
# [('UKIP', 'NN')]
# UKIP
# [('BBC', 'NNP')]
# BBC
# [('Herald', 'NNP')]
# Herald
# [('UKIP', 'NNP'), ('Scotland', 'NNP')]
# UKIP
# [('Times', 'NNP')]
# Times
# [('US', 'NNP')]
# US
# [('United', 'NNP'), ('Arab', 'NNP'), ('Emirates', 'NNP')]
# United
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP')]
# UK
# [('BBC', 'NNP')]
# BBC
# [('Doha', 'NNP')]
# Doha
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('Common', 'NNP')]
# Common
# [('Catholic', 'NNP')]
# Catholic
# [('Aids', 'NNP')]
# Aids
# [('Tories', 'NNPS')]
# Tories
# [('MPs', 'NNP')]
# MPs
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('UK', 'NNP')]
# UK
# [('Lib', 'NNP'), ('Dem', 'NNP')]
# Lib
# [('National', 'NNP'), ('Audit', 'NNP')]
# National
# [('BBC', 'NNP')]
# BBC
# [('European', 'JJ'), ('Commissioner', 'NNP'), ('Peter', 'NNP'), ('Mandelson', 'NNP')]
# European
# [('National', 'NNP'), ('Statistics', 'NNPS')]
# National
# [('Federation', 'NNP')]
# Federation
# [('Small', 'NNP'), ('Businesses', 'NNP')]
# Small
# [('Ivory', 'NNP'), ('Coast', 'NNP')]
# Ivory
# [('Aids', 'NNP')]
# Aids
# [('Department', 'NNP')]
# Department
# [('International', 'NNP'), ('Development', 'NNP')]
# International
# [('International', 'NNP'), ('Finance', 'NNP')]
# International
# [('UK', 'NNP')]
# UK
# [('High', 'JJ'), ('Court', 'NNP')]
# High
# [('RAF', 'NNP'), ('Fairford', 'NNP')]
# RAF
# [('Appeal', 'NNP'), ('Court', 'NNP')]
# Appeal
# [('High', 'JJ'), ('Court', 'NNP')]
# High
# [('RAF', 'NNP'), ('Fairford', 'NNP')]
# RAF
# [('Lord', 'NNP'), ('Justices', 'NNP'), ('Clarke', 'NNP')]
# Lord
# [('Gloucestershire', 'NNP')]
# Gloucestershire
# [('RAF', 'NNP'), ('Fairford', 'NNP')]
# RAF
# [('UK', 'NNP')]
# UK
# [('RAF', 'NNP'), ('Fairford', 'NNP')]
# RAF
# [('Fairford', 'NNP')]
# Fairford
# [('European', 'JJ'), ('Court', 'NNP')]
# European
# [('Human', 'NNP'), ('Rights', 'NNPS')]
# Human
# [('Liberty', 'NNP')]
# Liberty
# [('Tories', 'NNPS')]
# Tories
# [('Lib', 'NNP')]
# Lib
# [('Lib', 'NNP'), ('Dems', 'NNP')]
# Lib
# [('MP', 'NNP')]
# MP
# [('BBC', 'NNP')]
# BBC
# [('Commons', 'NNPS')]
# Commons
# [('Parliament', 'NNP')]
# Parliament
# [('Countryside', 'NNP')]
# Countryside
# [('Countryside', 'NNP'), ('Alliance', 'NNP')]
# Countryside
# [('Public', 'NNP'), ('Prosecutions', 'NNPS')]
# Public
# [('House', 'NNP')]
# House
# [('Lords', 'NNPS')]
# Lords
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('Beaufort', 'NNP'), ('Hunt', 'NNP')]
# Beaufort
# [('Conservatives', 'NNPS')]
# Conservatives
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP')]
# UK
# [('Foreign', 'NNP')]
# Foreign
# [('Tsunami', 'NNP')]
# Tsunami
# [('BBC', 'NNP')]
# BBC
# [('UK', 'NNP')]
# UK
# [('Sri', 'NNP'), ('Lanka', 'NNP')]
# Sri
# [('International', 'NNP'), ('Development', 'NNP')]
# International
# [('RAF', 'NNP')]
# RAF
# [('Royal', 'NNP'), ('Fleet', 'NNP')]
# Royal
# [('HMS', 'NNP'), ('Chatham', 'NNP')]
# HMS
# [('Bayleaf', 'NNP')]
# Bayleaf
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('BBC', 'NNP'), ('One', 'NNP')]
# BBC
# [('BBC', 'NNP')]
# BBC
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Foreign', 'NNP')]
# Foreign
# [('Zimbabwe', 'NNP')]
# Zimbabwe
# [('BBC', 'NNP')]
# BBC
# [('One', 'NNP')]
# One
# [('UK', 'NNP')]
# UK
# [('Nato', 'NNP')]
# Nato
# [('Countryside', 'NNP'), ('Alliance', 'NNP')]
# Countryside
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('BBC', 'NNP')]
# BBC
# [('Postbridge', 'NNP')]
# Postbridge
# [('BBC', 'NNP')]
# BBC
# [('Beaufort', 'NNP'), ('Hunt', 'NNP')]
# Beaufort
# [('BBC', 'NNP')]
# BBC
# [('Leicestershire', 'NNP')]
# Leicestershire
# [('Countryside', 'NNP'), ('Alliance', 'NNP')]
# Countryside
# [('Association', 'NNP')]
# Association
# [('UK', 'NNP')]
# UK
# [('National', 'NNP'), ('Audit', 'NNP')]
# National
# [('European', 'JJ'), ('Court', 'NNP')]
# European
# [('Auditors', 'NNPS')]
# Auditors
# [('NAO', 'NNP')]
# NAO
# [('European', 'NNP')]
# European
# [('Community', 'NNP')]
# Community
# [('Commons', 'NNP')]
# Commons
# [('UK', 'NNP')]
# UK
# [('Community', 'NNP')]
# Community
# [('UK', 'NNP')]
# UK
# [('Commission', 'NNP')]
# Commission
# [('European', 'NNP')]
# European
# [('NAO', 'NNP')]
# NAO
# [('NAO', 'NNP')]
# NAO
# [('UK', 'NNP')]
# UK
# [('Line', 'NNP')]
# Line
# [('Control', 'NNP')]
# Control
# [('Line', 'NNP')]
# Line
# [('Control', 'NNP')]
# Control
# [('Golden', 'NNP'), ('Temple', 'NNP')]
# Golden
# [('Sindh', 'NNP')]
# Sindh
# [('Department', 'NNP')]
# Department
# [('International', 'NNP'), ('Development', 'NNP')]
# International
# [('Survivors', 'NNPS'), ('Fund', 'NNP')]
# Survivors
# [('SURF', 'NNP')]
# SURF
# [('ID', 'NNP')]
# ID
# [('Labour', 'NNP')]
# Labour
# [('Tory', 'NNP')]
# Tory
# [('Lib', 'NNP'), ('Dems', 'NNP')]
# Lib
# [('ID', 'NNP')]
# ID
# [('Conservatives', 'NNPS')]
# Conservatives
# [('BBC', 'NNP')]
# BBC
# [('ID', 'NNP')]
# ID
# [('Tories', 'NNPS')]
# Tories
# [('ID', 'NNP')]
# ID
# [('ID', 'NNP')]
# ID
# [('ID', 'NNP')]
# ID
# [('Bar', 'NNP'), ('Council', 'NNP')]
# Bar
# [('ID', 'NNP')]
# ID
# [('EU', 'NNP'), ('Constitution', 'NNP')]
# EU
# [('United', 'NNP'), ('Kingdom', 'NNP')]
# United
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('UK', 'NNP')]
# UK
# [('Foreign', 'NNP')]
# Foreign
# [('Cabinet', 'NNP')]
# Cabinet
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP'), ('Independence', 'NNP'), ('Party', 'NNP')]
# UK
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('Liberal', 'JJ'), ('Democrat', 'NNP')]
# Liberal
# [('BBC', 'NNP')]
# BBC
# [('Financial', 'NNP'), ('Times', 'NNP')]
# Financial
# [('MPs', 'NNP')]
# MPs
# [('NEC', 'NNP')]
# NEC
# [('NEC', 'NNP')]
# NEC
# [('BBC', 'NNP')]
# BBC
# [('MPs', 'NNP')]
# MPs
# [('National', 'NNP'), ('Executive', 'NNP'), ('Committee', 'NNP')]
# National
# [('NEC', 'NNP')]
# NEC
# [('MP', 'NNP')]
# MP
# [('Quentin', 'NNP'), ('Davies', 'NNPS')]
# Quentin
# [('MP', 'NNP')]
# MP
# [('Parliamentary', 'NNP')]
# Parliamentary
# [('Nairobi', 'NNP'), ('Serena', 'NNP'), ('Hotel', 'NNP')]
# Nairobi
# [('Anglican', 'NNP')]
# Anglican
# [('House', 'NNP')]
# House
# [('Commons', 'NNPS'), ('International', 'NNP'), ('Development', 'NNP'), ('Committee', 'NNP')]
# Commons
# [('Candidate', 'NNP')]
# Candidate
# [('BNP', 'NNP')]
# BNP
# [('UK', 'NNP'), ('Independence', 'NNP'), ('Party', 'NNP')]
# UK
# [('UKIP', 'NNP')]
# UKIP
# [('National', 'NNP'), ('Party', 'NNP')]
# National
# [('BNP', 'NNP')]
# BNP
# [('Suffolk', 'NNP'), ('Coastal', 'NNP')]
# Suffolk
# [('BNP', 'NNP')]
# BNP
# [('UKIP', 'NNP')]
# UKIP
# [('BNP', 'NNP')]
# BNP
# [('BNP', 'NNP')]
# BNP
# [('UKIP', 'NNP')]
# UKIP
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('ILW', 'NNP')]
# ILW
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP')]
# UK
# [('Nuclear', 'NNP'), ('Fuels', 'NNP')]
# Nuclear
# [('Intermediate', 'NNP')]
# Intermediate
# [('UK', 'NNP')]
# UK
# [('Sellafield', 'NNP')]
# Sellafield
# [('Department', 'NNP')]
# Department
# [('Commons', 'NNP')]
# Commons
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('Lib', 'NNP'), ('Dem', 'NNP')]
# Lib
# [('Treasury', 'NNP')]
# Treasury
# [('DTI', 'NNP')]
# DTI
# [('Energy', 'NNP'), ('Act', 'NNP')]
# Energy
# [('Labour', 'JJ')]
# Labour
# [('UK', 'NNP')]
# UK
# [('Labour', 'JJ')]
# Labour
# [('MPs', 'NNP')]
# MPs
# [('Labour', 'NNP'), ('Party', 'NNP')]
# Labour
# [('UK', 'NNP')]
# UK
# [('BBC', 'NNP')]
# BBC
# [('Labour', 'NNP')]
# Labour
# [('Tories', 'NNPS')]
# Tories
# [('Shrewsbury', 'NNP')]
# Shrewsbury
# [('Election', 'NNP'), ('Court', 'NNP')]
# Election
# [('QC', 'NNP')]
# QC
# [('Birmingham', 'NNP')]
# Birmingham
# [('Midlands', 'NNP')]
# Midlands
# [('General', 'JJ'), ('Election', 'NNP')]
# General
# [('Election', 'NNP'), ('Court', 'NNP')]
# Election
# [('Liberal', 'NNP')]
# Liberal
# [('Bordesley', 'NNP'), ('Green', 'NNP')]
# Bordesley
# [('Authority', 'NNP')]
# Authority
# [('BBC', 'NNP')]
# BBC
# [('BBC', 'NNP')]
# BBC
# [('Labour', 'NNP')]
# Labour
# [('Respect', 'NNP'), ('Coalition', 'NNP')]
# Respect
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP')]
# UK
# [('Metropolitan', 'NNP')]
# Metropolitan
# [('MI5', 'NNP')]
# MI5
# [('UK', 'NNP')]
# UK
# [('Guantanamo', 'NNP'), ('Bay', 'NNP')]
# Guantanamo
# [('BBC', 'NNP')]
# BBC
# [('Pentagon', 'NNP')]
# Pentagon
# [('UK', 'JJ')]
# UK
# [('US', 'NNP')]
# US
# [('Terrorism', 'NNP')]
# Terrorism
# [('RAF', 'NNP'), ('Northolt', 'NNP')]
# RAF
# [('Muslim', 'NNP'), ('Safety', 'NNP'), ('Forum', 'NNP')]
# Muslim
# [('Muslim', 'NNP'), ('Council', 'NNP')]
# Muslim
# [('Hunting', 'NNP'), ('Act', 'NNP')]
# Hunting
# [('BBC', 'NNP')]
# BBC
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('Hunting', 'NNP'), ('Act', 'NNP')]
# Hunting
# [('Bicester', 'NNP'), ('Hunt', 'NNP')]
# Bicester
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('Bicester', 'NNP'), ('Hunt', 'NNP')]
# Bicester
# [('Lib', 'NNP'), ('Dems', 'NNP')]
# Lib
# [('UK', 'NNP')]
# UK
# [('Tories', 'NNPS')]
# Tories
# [('UK', 'NNP')]
# UK
# [('BBC', 'NNP')]
# BBC
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP')]
# UK
# [('Liberal', 'NNP')]
# Liberal
# [('Tories', 'NNPS')]
# Tories
# [('Nazi', 'NNP')]
# Nazi
# [('Nazi', 'NNP')]
# Nazi
# [('IOC', 'NNP')]
# IOC
# [('International', 'NNP')]
# International
# [('London', 'NNP'), ('Assembly', 'NNP')]
# London
# [('Board', 'NNP')]
# Board
# [('Standards', 'NNP'), ('Board', 'NNP')]
# Standards
# [('BBC', 'NNP')]
# BBC
# [('Newsnight', 'NNP')]
# Newsnight
# [('General', 'NNP'), ('Musharraf', 'NNP')]
# General
# [('High', 'NNP'), ('Commissioner', 'NNP')]
# High
# [('BBC', 'NNP')]
# BBC
# [('Mirror', 'NNP')]
# Mirror
# [('Gen', 'NNP'), ('Musharraf', 'NNP')]
# Gen
# [('Gen', 'NNP')]
# Gen
# [('New', 'NNP'), ('Year', 'NNP'), ('Honours', 'NNP')]
# New
# [('New', 'NNP'), ('Year', 'NNP')]
# New
# [('Commander', 'NNP')]
# Commander
# [('Commons', 'NNP')]
# Commons
# [('Liberal', 'JJ'), ('Democrats', 'NNPS')]
# Liberal
# [('Immigration', 'NNP')]
# Immigration
# [('Nationality', 'NNP'), ('Department', 'NNP')]
# Nationality
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Civil', 'NNP'), ('Service', 'NNP')]
# Civil
# [('Treasury', 'NNP')]
# Treasury
# [('Department', 'NNP')]
# Department
# [('Employment', 'NNP')]
# Employment
# [('Work', 'NNP')]
# Work
# [('Civil', 'NNP'), ('Service', 'NNP')]
# Civil
# [('Inland', 'NNP'), ('Revenue', 'NNP')]
# Inland
# [('Child', 'NNP'), ('Support', 'NNP'), ('Agency', 'NNP')]
# Child
# [('CSA', 'NNP')]
# CSA
# [('NatWest', 'NNP')]
# NatWest
# [('NHS', 'NNP')]
# NHS
# [('GCSEs', 'NNP')]
# GCSEs
# [('UK', 'NNP'), ('Independence', 'NNP'), ('Party', 'NNP')]
# UK
# [('BBC', 'NNP')]
# BBC
# [('BBC', 'NNP'), ('One', 'NNP')]
# BBC
# [('BBC', 'NNP')]
# BBC
# [('Muslim', 'NNP')]
# Muslim
# [('Cabinet', 'NNP')]
# Cabinet
# [('Manchester', 'NNP'), ('High', 'NNP'), ('School', 'NNP')]
# Manchester
# [('BBC', 'NNP')]
# BBC
# [('MEP', 'NNP')]
# MEP
# [('BBC', 'NNP')]
# BBC
# [('Vauxhall', 'NNP'), ('Corsa', 'NNP')]
# Vauxhall
# [('MEP', 'NNP')]
# MEP
# [('UK', 'NNP'), ('Independence', 'NNP'), ('Party', 'NNP')]
# UK
# [('European', 'JJ'), ('Parliament', 'NNP')]
# European
# [('UKIP', 'NNP')]
# UKIP
# [('General', 'NNP'), ('Election', 'NNP')]
# General
# [('UKIP', 'NNP')]
# UKIP
# [('Commons', 'NNPS')]
# Commons
# [('House', 'NNP')]
# House
# [('RAC', 'NNP')]
# RAC
# [('Environmental', 'NNP')]
# Environmental
# [('People', 'NNP')]
# People
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Tory', 'NNP')]
# Tory
# [('Tory', 'JJ')]
# Tory
# [('Liberal', 'JJ'), ('Democrats', 'NNPS')]
# Liberal
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Tory', 'NNP')]
# Tory
# [('Tories', 'NNP')]
# Tories
# [('BBC', 'NNP')]
# BBC
# [('Lib', 'NNP'), ('Dems', 'NNPS')]
# Lib
# [('Tories', 'NNPS')]
# Tories
# [('Liberal', 'NNP'), ('Democrats', 'NNPS')]
# Liberal
# [('House', 'NNP')]
# House
# [('MacDonald', 'NNP')]
# MacDonald
# [('BBC', 'NNP')]
# BBC
# [('Muslim', 'NNP')]
# Muslim
# [('Security', 'NNP'), ('Act', 'NNP')]
# Security
# [('MacDonald', 'NNP')]
# MacDonald
# [('Special', 'JJ'), ('Immigration', 'NNP'), ('Appeals', 'NNP'), ('Commission', 'NNP')]
# Special
# [('SIAC', 'NNP')]
# SIAC
# [('MacDonald', 'NNP')]
# MacDonald
# [('Radio', 'NNP')]
# Radio
# [('Special', 'JJ'), ('Advocates', 'NNP')]
# Special
# [('House', 'NNP')]
# House
# [('European', 'NNP'), ('Council', 'NNP')]
# European
# [('Tory', 'NNP')]
# Tory
# [('TUC', 'NNP')]
# TUC
# [('TUC', 'NNP')]
# TUC
# [('Health', 'NNP')]
# Health
# [('TUC', 'NNP')]
# TUC
# [('Hazards', 'NNP')]
# Hazards
# [('TUC', 'NNP')]
# TUC
# [('Health', 'NNP')]
# Health
# [('House', 'NNP')]
# House
# [('Lords', 'NNPS')]
# Lords
# [('BBC', 'NNP')]
# BBC
# [('European', 'JJ'), ('Commissioner', 'NNP')]
# European
# [('Lords', 'NNP')]
# Lords
# [('House', 'NNP')]
# House
# [('Lords', 'NNPS')]
# Lords
# [('Lords', 'NNPS')]
# Lords
# [('Lord', 'NNP'), ('Kinnock', 'NNP')]
# Lord
# [('McConnell', 'NNP')]
# McConnell
# [('MSPs', 'NNP')]
# MSPs
# [('Scottish', 'JJ'), ('Parliament', 'NNP')]
# Scottish
# [('McConnell', 'NNP')]
# McConnell
# [('Scottish', 'JJ'), ('Executive', 'NNP')]
# Scottish
# [('McConnell', 'NNP')]
# McConnell
# [('Make', 'NNP'), ('Poverty', 'NNP')]
# Make
# [('Koh', 'NNP'), ('Phi', 'NNP'), ('Phi', 'NNP')]
# Koh
# [('MPs', 'NNP')]
# MPs
# [('Commons', 'NNP')]
# Commons
# [('BBC', 'NNP'), ('Two', 'CD')]
# BBC
# [('BBC', 'NNP'), ('Radio', 'NNP')]
# BBC
# [('BBC', 'NNP'), ('Radio', 'NNP')]
# BBC
# [('News', 'NNP')]
# News
# [('World', 'NNP')]
# World
# [('BBC', 'NNP')]
# BBC
# [('BBC', 'NNP'), ('One', 'NNP')]
# BBC
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('Environmental', 'NNP'), ('Audit', 'NNP'), ('Committee', 'NNP')]
# Environmental
# [('Defra', 'NNP')]
# Defra
# [('BBC', 'NNP')]
# BBC
# [('Environmental', 'NNP'), ('Audit', 'NNP'), ('Committee', 'NNP')]
# Environmental
# [('Treasury', 'NNP')]
# Treasury
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('Commons', 'NNP')]
# Commons
# [('MPs', 'NNP')]
# MPs
# [('Committee', 'NNP')]
# Committee
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('Ford', 'NNP')]
# Ford
# [('MPs', 'NNP')]
# MPs
# [('Sentencing', 'NNP'), ('Guidelines', 'NNPS'), ('Council', 'NNP')]
# Sentencing
# [('SGC', 'NNP')]
# SGC
# [('SGC', 'NNP')]
# SGC
# [('Parliament', 'NNP')]
# Parliament
# [('Parliament', 'NNP')]
# Parliament
# [('Liberal', 'NNP'), ('Democrat', 'NNP')]
# Liberal
# [('MPs', 'NNP')]
# MPs
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('MPs', 'NNP')]
# MPs
# [('Hunting', 'NNP'), ('Act', 'NNP')]
# Hunting
# [('Hunting', 'NNP')]
# Hunting
# [('Hunting', 'NNP'), ('Act', 'NNP')]
# Hunting
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('Hospital', 'NNP')]
# Hospital
# [('BBC', 'NNP'), ('Radio', 'NNP')]
# BBC
# [('Powys', 'NNP')]
# Powys
# [('Welsh', 'NNP'), ('Assembly', 'NNP')]
# Welsh
# [('Hereford', 'NNP'), ('Hospitals', 'NNP')]
# Hereford
# [('Club2School', 'NN')]
# Club2School
# [('UK', 'NNP')]
# UK
# [('National', 'NNP'), ('Lottery', 'NNP')]
# National
# [('UK', 'NNP')]
# UK
# [('Key', 'NNP')]
# Key
# [('Key', 'NNP')]
# Key
# [('Tories', 'NNPS')]
# Tories
# [('Evangelical', 'NNP'), ('Christian', 'NNP')]
# Evangelical
# [('Bell', 'NNP')]
# Bell
# [('Hansard', 'NNP'), ('Society', 'NNP')]
# Hansard
# [('Muslim', 'NNP')]
# Muslim
# [('Bell', 'NNP')]
# Bell
# [('Ofsted', 'NNP')]
# Ofsted
# [('Muslim', 'NNP')]
# Muslim
# [('Scottish', 'NNP')]
# Scottish
# [('Session', 'NNP')]
# Session
# [('Barlinnie', 'NNP')]
# Barlinnie
# [('European', 'NNP'), ('Convention', 'NNP')]
# European
# [('Human', 'NNP'), ('Rights', 'NNPS')]
# Human
# [('European', 'NNP'), ('Convention', 'NNP')]
# European
# [('Human', 'NNP'), ('Rights', 'NNPS')]
# Human
# [('Lord', 'NNP'), ('Hamilton', 'NNP')]
# Lord
# [('Scottish', 'JJ'), ('National', 'NNP'), ('Party', 'NNP')]
# Scottish
# [('SNP', 'NNP')]
# SNP
# [('Scottish', 'JJ'), ('Executive', 'NNP')]
# Scottish
# [('Scottish', 'JJ'), ('National', 'NNP'), ('Party', 'NNP')]
# Scottish
# [('Scottish', 'NNP')]
# Scottish
# [('BBC', 'NNP'), ('Scotland', 'NNP')]
# BBC
# [('Sergeant', 'NNP'), ('Keith', 'NNP')]
# Sergeant
# [('Labour', 'NNP')]
# Labour
# [('NHS', 'NNP')]
# NHS
# [('Gateshead', 'NNP')]
# Gateshead
# [('GP', 'NNP')]
# GP
# [('Conservative', 'NNP')]
# Conservative
# [('ERM', 'NNP')]
# ERM
# [('Conservative', 'NNP'), ('Party', 'NNP')]
# Conservative
# [('Gypsy', 'NNP')]
# Gypsy
# [('MPs', 'NNP')]
# MPs
# [('Gypsies', 'NNPS')]
# Gypsies
# [('MPs', 'NNP')]
# MPs
# [('Traveller', 'NNP'), ('Law', 'NNP'), ('Reform', 'NNP'), ('Coalition', 'NNP')]
# Traveller
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('UK', 'NNP')]
# UK
# [('DNA', 'NNP')]
# DNA
# [('Llyn', 'NNP'), ('Peninsula', 'NNP')]
# Llyn
# [('MP', 'NNP')]
# MP
# [('Merionnydd', 'NNP'), ('Nant', 'NNP'), ('Conwy', 'NNP')]
# Merionnydd
# [('Parliamentary', 'JJ'), ('Leader', 'NNP')]
# Parliamentary
# [('BBC', 'NNP'), ('Wales', 'NNP')]
# BBC
# [('Lord', 'NNP'), ('Roberts', 'NNP')]
# Lord
# [('IRA', 'NNP')]
# IRA
# [('Hatfield', 'NNP')]
# Hatfield
# [('Hatfield', 'NNP')]
# Hatfield
# [('Countryside', 'NNP'), ('Alliance', 'NNP')]
# Countryside
# [('Appeal', 'NNP'), ('Court', 'NNP')]
# Appeal
# [('Hunting', 'NNP'), ('Act', 'NNP')]
# Hunting
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('BBC', 'NNP')]
# BBC
# [('BBC', 'NNP')]
# BBC
# [('Countryside', 'NNP'), ('Alliance', 'NNP')]
# Countryside
# [('Quorn', 'NNP')]
# Quorn
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('Countryside', 'NNP'), ('Alliance', 'NNP')]
# Countryside
# [('Hunting', 'NNP'), ('Act', 'NNP')]
# Hunting
# [('League', 'NNP'), ('Against', 'NNP'), ('Cruel', 'NNP'), ('Sports', 'NNP')]
# League
# [('RSPCA', 'NNP')]
# RSPCA
# [('Association', 'NNP')]
# Association
# [('Mental', 'NNP'), ('Capacity', 'NNP'), ('Bill', 'NNP')]
# Mental
# [('Commons', 'NNPS')]
# Commons
# [('Catholic', 'NNP')]
# Catholic
# [('MPs', 'NNP')]
# MPs
# [('Constitutional', 'NNP')]
# Constitutional
# [('House', 'NNP')]
# House
# [('BBC', 'NNP')]
# BBC
# [('Parliament', 'NNP')]
# Parliament
# [('BBC', 'NNP')]
# BBC
# [('PM', 'NNP'), ('Tony', 'NNP'), ('Blair', 'NNP')]
# PM
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Waverley', 'NNP'), ('Sports', 'NNP'), ('College', 'NNP')]
# Waverley
# [('BBC', 'NNP')]
# BBC
# [('PE', 'NNP')]
# PE
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Parliament', 'NNP')]
# Parliament
# [('UK', 'NNP')]
# UK
# [('Commons', 'NNP')]
# Commons
# [('House', 'NNP')]
# House
# [('Guildford', 'NNP'), ('Four', 'NNP')]
# Guildford
# [('BBC', 'NNP')]
# BBC
# [('Belmarsh', 'NNP')]
# Belmarsh
# [('Law', 'NNP'), ('Lords', 'NNP')]
# Law
# [('UK', 'NNP')]
# UK
# [('House', 'NNP')]
# House
# [('Tories', 'NNPS')]
# Tories
# [('Lib', 'NNP'), ('Dems', 'NNP')]
# Lib
# [('Liberal', 'JJ'), ('Democrat', 'NNP')]
# Liberal
# [('UK', 'NNP')]
# UK
# [('Former', 'NNP'), ('Northern', 'NNP')]
# Former
# [('Conservative', 'NNP')]
# Conservative
# [('Margaret', 'NNP'), ('Thatcher', 'NNP')]
# Margaret
# [('IRA', 'NNP')]
# IRA
# [('Maze', 'NNP')]
# Maze
# [('Catholic', 'NNP')]
# Catholic
# [('New', 'NNP'), ('University', 'NNP')]
# New
# [('Ulster', 'NNP')]
# Ulster
# [('Ulster', 'NNP')]
# Ulster
# [('University', 'NNP')]
# University
# [('Ulster', 'NNP')]
# Ulster
# [('SDLP', 'NNP')]
# SDLP
# [('Tory', 'NNP'), ('Party', 'NNP')]
# Tory
# [('Cabinet', 'NNP')]
# Cabinet
# [('MPs', 'NNP')]
# MPs
# [('Disability', 'NNP'), ('Bill', 'NNP')]
# Disability
# [('Conservative', 'NNP')]
# Conservative
# [('Parliament', 'NNP')]
# Parliament
# [('Lord', 'NNP'), ('Goldsmith', 'NNP')]
# Lord
# [('Lord', 'NNP'), ('Goldsmith', 'NNP')]
# Lord
# [('Commons', 'NNP')]
# Commons
# [('BBC', 'NNP')]
# BBC
# [('Matrix', 'NNP'), ('Chambers', 'NNPS')]
# Matrix
# [('Commons', 'NNP')]
# Commons
# [('Downing', 'NNP'), ('Street', 'NNP')]
# Downing
# [('House', 'NNP')]
# House
# [('Conservatives', 'NNPS')]
# Conservatives
# [('Liberal', 'JJ'), ('Democrats', 'NNPS')]
# Liberal
# [('Security', 'NNP'), ('Council', 'NNP')]
# Security
# [('BNP', 'NNP')]
# BNP
# [('National', 'NNP'), ('Party', 'NNP')]
# National
# [('Muslim', 'NNP')]
# Muslim
# [('Swansea', 'NNP'), ('Bay', 'NNP'), ('Race', 'NNP'), ('Equality', 'NNP'), ('Council', 'NNP')]
# Swansea
# [('BNP', 'NNP')]
# BNP
# [('BNP', 'NNP')]
# BNP
# [('BNP', 'NNP')]
# BNP
# [('BNP', 'NNP')]
# BNP
# [('BNP', 'NNP')]
# BNP
# [('BNP', 'NNP')]
# BNP
# [('UAF', 'NNP')]
# UAF
# [('BNP', 'NNP')]
# BNP
# [('Muslim', 'NNP')]
# Muslim
# [('Muslim', 'NNP')]
# Muslim
# [('Nazi', 'NNP')]
# Nazi
# [('Labour', 'NNP'), ('Party', 'NNP')]
# Labour
# [('Labour', 'NNP'), ('Party', 'NNP')]
# Labour
# [('Culture', 'NNP')]
# Culture
# [('International', 'NNP')]
# International
# [('Standards', 'NNP'), ('Board', 'NNP')]
# Standards
# [('UK', 'NNP')]
# UK
# [('Tories', 'NNPS')]
# Tories
# [('Culture', 'NNP')]
# Culture
# [('Rank', 'NNP'), ('Group', 'NNP')]
# Rank
# [('Daily', 'NNP'), ('Mail', 'NNP')]
# Daily
# [('Gen', 'NNP'), ('Pervez', 'NNP'), ('Musharraf', 'NNP')]
# Gen
# [('Mirror', 'NNP')]
# Mirror
# [('Directorate', 'NNP')]
# Directorate
# [('TimeWarner', 'NNP')]
# TimeWarner
# [('TimeWarner', 'NNP')]
# TimeWarner
# [('Warner', 'NNP'), ('Bros', 'NNP')]
# Warner
# [('AOL', 'NNP')]
# AOL
# [('AOL', 'NNP')]
# AOL
# [('AOL', 'NNP')]
# AOL
# [('TimeWarner', 'NNP')]
# TimeWarner
# [('AOL', 'NNP')]
# AOL
# [('TimeWarner', 'NNP')]
# TimeWarner
# [('US', 'NNP'), ('Securities', 'NNPS'), ('Exchange', 'NNP'), ('Commission', 'NNP')]
# US
# [('SEC', 'NNP')]
# SEC
# [('Lord', 'NNP')]
# Lord
# [('TimeWarner', 'NNP')]
# TimeWarner
# [('TimeWarner', 'NNP')]
# TimeWarner
# [('TimeWarner', 'NN')]
# TimeWarner
# [('AOL', 'NNP')]
# AOL
# [('SEC', 'NNP')]
# SEC
# [('AOL', 'NNP'), ('Europe', 'NNP')]
# AOL
# [('AOL', 'NNP'), ('Europe', 'NNP')]
# AOL
# [('Federal', 'NNP'), ('Reserve', 'NNP')]
# Federal
# [('Federal', 'NNP'), ('Reserve', 'NNP')]
# Federal
# [('US', 'NNP')]
# US
# [('Bank', 'NNP')]
# Bank
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Yukos', 'NNP')]
# Yukos
# [('Menatep', 'NNP'), ('Group', 'NNP')]
# Menatep
# [('Menatep', 'NNP'), ('Group', 'NNP')]
# Menatep
# [('Reuters', 'NNP')]
# Reuters
# [('Rosneft', 'NN')]
# Rosneft
# [('US', 'NNP')]
# US
# [('BA', 'NNP')]
# BA
# [('BA', 'NNP')]
# BA
# [('BA', 'NNP')]
# BA
# [('Dresdner', 'NNP'), ('Kleinwort', 'NNP'), ('Wasserstein', 'NNP')]
# Dresdner
# [('BA', 'NNP')]
# BA
# [('BA', 'NNP')]
# BA
# [('BNP', 'NNP'), ('Paribas', 'NNP')]
# BNP
# [('BA', 'NNP')]
# BA
# [('BA', 'NNP')]
# BA
# [('Club', 'NNP')]
# Club
# [('Financial', 'NNP'), ('Times', 'NNP')]
# Financial
# [('Seagram', 'NNP')]
# Seagram
# [('LVMH', 'NNP')]
# LVMH
# [('Creek', 'NNP')]
# Creek
# [('WSJ', 'NNP')]
# WSJ
# [('Lehman', 'NNP'), ('Brothers', 'NNPS')]
# Lehman
# [('US', 'NNP')]
# US
# [('Labor', 'NNP'), ('Department', 'NNP')]
# Labor
# [('Labor', 'NNP'), ('Department', 'NNP')]
# Labor
# [('BMO', 'NNP')]
# BMO
# [('ClearView', 'NNP'), ('Economics', 'NNP')]
# ClearView
# [('G7', 'NNP')]
# G7
# [('United', 'NNP'), ('Nations', 'NNPS')]
# United
# [('World', 'NNP'), ('Bank', 'NNP')]
# World
# [('IMF', 'NNP')]
# IMF
# [('G20', 'NNP')]
# G20
# [('UK', 'NNP')]
# UK
# [('G7', 'NNP')]
# G7
# [('IMF', 'NNP')]
# IMF
# [('Food', 'NNP')]
# Food
# [('Agriculture', 'NNP'), ('Organisation', 'NNP')]
# Agriculture
# [('Food', 'NNP')]
# Food
# [('Agriculture', 'NNP'), ('Organisation', 'NNP')]
# Agriculture
# [('FAO', 'NNP')]
# FAO
# [('FAO', 'NNP')]
# FAO
# [('Altria', 'NNP'), ('Group', 'NNP')]
# Altria
# [('RJ', 'NNP'), ('Reynolds', 'NNP'), ('Tobacco', 'NNP')]
# RJ
# [('District', 'NNP')]
# District
# [('Reynolds', 'NNP')]
# Reynolds
# [('Ask', 'NNP'), ('Jeeves', 'NNPS')]
# Ask
# [('National', 'NNP'), ('Development', 'NNP')]
# National
# [('BBC', 'NNP')]
# BBC
# [('Mitsubishi', 'NNP')]
# Mitsubishi
# [('SUV', 'NNP')]
# SUV
# [('Mitsubishi', 'NNP')]
# Mitsubishi
# [('SUVs', 'NNP')]
# SUVs
# [('Mitsubishi', 'NNP'), ('Motors', 'NNPS')]
# Mitsubishi
# [('Mitsubishi', 'NNP')]
# Mitsubishi
# [('DaimlerChrylser', 'NNP')]
# DaimlerChrylser
# [('Mitsubishi', 'NNP'), ('Motors', 'NNP')]
# Mitsubishi
# [('Mitsubishi', 'NNP'), ('Motors', 'NNPS')]
# Mitsubishi
# [('Nissan', 'NNP')]
# Nissan
# [('Telegraph', 'NNP')]
# Telegraph
# [('Daily', 'NNP')]
# Daily
# [('Telegraph', 'NNP'), ('Group', 'NNP')]
# Telegraph
# [('National', 'NNP'), ('Union', 'NNP')]
# National
# [('National', 'NNP'), ('Union', 'NNP')]
# National
# [('Journalists', 'NNPS')]
# Journalists
# [('NUJ', 'NNP')]
# NUJ
# [('NUJ', 'NNP')]
# NUJ
# [('Telegraph', 'NNP')]
# Telegraph
# [('Telegraph', 'NNP')]
# Telegraph
# [('Telegraph', 'NNP'), ('Group', 'NNP')]
# Telegraph
# [('Barclay', 'NNP')]
# Barclay
# [('Hollinger', 'NNP'), ('International', 'NNP')]
# Hollinger
# [('Daily', 'NNP'), ('Telegraph', 'NNP')]
# Daily
# [('News', 'NNP'), ('Corp', 'NNP')]
# News
# [('News', 'NNP'), ('International', 'NNP')]
# News
# [('Sun', 'NNP')]
# Sun
# [('News', 'NNP')]
# News
# [('Guardian', 'JJ'), ('Media', 'NNP'), ('Group', 'NNP')]
# Guardian
# [('Daily', 'NNP'), ('Mail', 'NNP')]
# Daily
# [('General', 'NNP'), ('Trust', 'NNP')]
# General
# [('European', 'JJ'), ('Commission', 'NNP')]
# European
# [('European', 'JJ')]
# European
# [('ELAA', 'NNP')]
# ELAA
# [('International', 'NNP'), ('Air', 'NNP'), ('Transport', 'NNP'), ('Association', 'NNP')]
# International
# [('IATA', 'NNP')]
# IATA
# [('Radio', 'NNP')]
# Radio
# [('European', 'JJ'), ('Regions', 'NNP'), ('Airline', 'NNP'), ('Association', 'NNP')]
# European
# [('ERAA', 'NNP')]
# ERAA
# [('ERAA', 'NNP')]
# ERAA
# [('EC', 'NNP')]
# EC
# [('ERAA', 'NNP')]
# ERAA
# [('European', 'JJ'), ('Commission', 'NNP')]
# European
# [('Commissioner', 'NNP')]
# Commissioner
# [('Transport', 'NNP')]
# Transport
# [('Union', 'NNP')]
# Union
# [('EC', 'NNP')]
# EC
# [('Parmalat', 'JJ')]
# Parmalat
# [('Parmalat', 'NNP')]
# Parmalat
# [('UBS', 'NNP')]
# UBS
# [('FDI', 'NNP')]
# FDI
# [('Investment', 'NNP')]
# Investment
# [('Sterling', 'NNP')]
# Sterling
# [('Tata', 'NNP')]
# Tata
# [('Sunovate', 'NNP')]
# Sunovate
# [('Dimension', 'NNP'), ('Data', 'NNP')]
# Dimension
# [('Leisure', 'NNP')]
# Leisure
# [('Rank', 'NNP')]
# Rank
# [('Goldman', 'NNP'), ('Sachs', 'NNP')]
# Goldman
# [('Pinewood', 'NNP')]
# Pinewood
# [('Hard', 'NNP'), ('Rock', 'NNP')]
# Hard
# [('DVDs', 'NNP')]
# DVDs
# [('DVDs', 'NNP')]
# DVDs
# [('VHS', 'NNP')]
# VHS
# [('UK', 'NNP')]
# UK
# [('Mecca', 'NNP'), ('Bingo', 'NNP')]
# Mecca
# [('Federal', 'NNP'), ('Labour', 'NNP'), ('Agency', 'NNP')]
# Federal
# [('Chancellor', 'NNP'), ('Gerhard', 'NNP')]
# Chancellor
# [('Hypovereinsbank', 'NNP')]
# Hypovereinsbank
# [('GDP', 'NNP')]
# GDP
# [('European', 'JJ'), ('Central', 'NNP'), ('Bank', 'NNP')]
# European
# [('Deutsche', 'NNP'), ('Bank', 'NNP')]
# Deutsche
# [('New', 'NNP'), ('Year', 'NNP')]
# New
# [('Commerce', 'NNP'), ('Department', 'NNP')]
# Commerce
# [('Bush', 'NNP')]
# Bush
# [('IXIS', 'NNP')]
# IXIS
# [('Yukos', 'NNP')]
# Yukos
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('European', 'JJ'), ('Court', 'NNP')]
# European
# [('Human', 'NNP'), ('Rights', 'NNP')]
# Human
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Deutsche', 'NNP'), ('Bank', 'NNP')]
# Deutsche
# [('Gazprom', 'NNP')]
# Gazprom
# [('GM', 'NNP')]
# GM
# [('General', 'NNP'), ('Motors', 'NNP')]
# General
# [('National', 'NNP'), ('Highway', 'NNP'), ('Traffic', 'NNP'), ('Safety', 'NNP'), ('Administration', 'NNP')]
# National
# [('NHTSA', 'NNP')]
# NHTSA
# [('SUVs', 'NNP')]
# SUVs
# [('GM', 'NNP')]
# GM
# [('Chevrolet', 'NNP'), ('Avalanche', 'NNP')]
# Chevrolet
# [('GMC', 'NNP'), ('Savana', 'NNP')]
# GMC
# [('NHTSA', 'NNP')]
# NHTSA
# [('SRX', 'NNP')]
# SRX
# [('GMC', 'NNP'), ('Envoys', 'NNP')]
# GMC
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('US', 'NNP')]
# US
# [('GM', 'NNP')]
# GM
# [('Mittal', 'NNP'), ('Steel', 'NNP')]
# Mittal
# [('ISG', 'NNP')]
# ISG
# [('US', 'NNP')]
# US
# [('International', 'NNP'), ('Steel', 'NNP'), ('Group', 'NNP')]
# International
# [('LNM', 'NNP'), ('Holdings', 'NNPS')]
# LNM
# [('Mittal', 'NNP'), ('Steel', 'NNP')]
# Mittal
# [('ISG', 'NNP')]
# ISG
# [('Mittal', 'JJ'), ('Steel', 'NNP')]
# Mittal
# [('Czech', 'NNP'), ('Republic', 'NNP')]
# Czech
# [('International', 'NNP'), ('Energy', 'NNP'), ('Agency', 'NNP')]
# International
# [('IEA', 'NNP')]
# IEA
# [('IEA', 'NNP')]
# IEA
# [('IEA', 'NNP')]
# IEA
# [('US', 'NNP'), ('Department', 'NNP')]
# US
# [('Energy', 'NNP')]
# Energy
# [('Yukos', 'NNP')]
# Yukos
# [('IEA', 'NNP')]
# IEA
# [('Venezuelan', 'NNP')]
# Venezuelan
# [('Vestey', 'NNP'), ('Group', 'NNP')]
# Vestey
# [('Vestey', 'NNP'), ('Group', 'NNP')]
# Vestey
# [('Reuters', 'NNPS')]
# Reuters
# [('Reuters', 'NNP')]
# Reuters
# [('Century', 'NNP')]
# Century
# [('Venezuelan', 'NNP')]
# Venezuelan
# [('Vestey', 'NNP'), ('Group', 'NNP')]
# Vestey
# [('Venezuelan', 'NNP')]
# Venezuelan
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('BBC', 'NNP')]
# BBC
# [('OECD', 'NNP')]
# OECD
# [('OECD', 'NNP')]
# OECD
# [('ISEQ', 'NNP')]
# ISEQ
# [('Bank', 'NNP')]
# Bank
# [('Reuters', 'NNP')]
# Reuters
# [('NCB', 'NNP'), ('Stockbrokers', 'NNP')]
# NCB
# [('Reuters', 'NNP')]
# Reuters
# [('Sumitomo', 'NNP'), ('Mitsui', 'NNP')]
# Sumitomo
# [('UFJ', 'NNP'), ('Holdings', 'NNP')]
# UFJ
# [('UFJ', 'NNP')]
# UFJ
# [('UFJ', 'NNP'), ('Holdings', 'NNPS')]
# UFJ
# [('UFJ', 'NNP')]
# UFJ
# [('UFJ', 'NNP')]
# UFJ
# [('Mitsubishi', 'NNP'), ('Tokyo', 'NNP')]
# Mitsubishi
# [('MTFG', 'NNP')]
# MTFG
# [('UFJ', 'NNP')]
# UFJ
# [('UFJ', 'NNP')]
# UFJ
# [('MTFG', 'NNP')]
# MTFG
# [('UFJ', 'NNP')]
# UFJ
# [('UFJ', 'NNP')]
# UFJ
# [('Daiwa', 'NNP'), ('Securities', 'NNPS')]
# Daiwa
# [('MG', 'NNP'), ('Rover', 'NNP')]
# MG
# [('Financial', 'NNP'), ('Times', 'NNP')]
# Financial
# [('UK', 'NNP')]
# UK
# [('FT', 'NNP')]
# FT
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('UK', 'NNP')]
# UK
# [('General', 'NNP'), ('Worker', 'NNP')]
# General
# [('Birmingham', 'NNP')]
# Birmingham
# [('SAIC', 'NNP')]
# SAIC
# [('FT', 'NNP')]
# FT
# [('SAIC', 'NNP')]
# SAIC
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('SAIC', 'NNP')]
# SAIC
# [('WPP', 'NNP')]
# WPP
# [('WPP', 'NNP')]
# WPP
# [('WPP', 'NNP')]
# WPP
# [('Grey', 'NNP'), ('Global', 'NNP')]
# Grey
# [('Reuters', 'NNP')]
# Reuters
# [('WPP', 'NNP')]
# WPP
# [('NOP', 'NNP')]
# NOP
# [('Ogilvy', 'NNP')]
# Ogilvy
# [('Cordiant', 'NNP'), ('Communications', 'NNP')]
# Cordiant
# [('WPP', 'NNP')]
# WPP
# [('US', 'NNP')]
# US
# [('FIFA', 'NNP')]
# FIFA
# [('WPP', 'NNP')]
# WPP
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Securities', 'NNPS')]
# Securities
# [('Exchange', 'NNP'), ('Commission', 'NNP')]
# Exchange
# [('SEC', 'NNP')]
# SEC
# [('Worldcom', 'NNP')]
# Worldcom
# [('Sox', 'NNP'), ('Act', 'NNP')]
# Sox
# [('SEC', 'NNP')]
# SEC
# [('Washington', 'NNP')]
# Washington
# [('UK', 'NNP')]
# UK
# [('CBI', 'NNP')]
# CBI
# [('US', 'NNP')]
# US
# [('CBI', 'NNP')]
# CBI
# [('SEC', 'NNP')]
# SEC
# [('SEC', 'NNP')]
# SEC
# [('CBI', 'NNP')]
# CBI
# [('BBC', 'NNP')]
# BBC
# [('SEC', 'NNP')]
# SEC
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('SEC', 'NNP')]
# SEC
# [('Mitsubishi', 'NNP'), ('Motors', 'NNPS')]
# Mitsubishi
# [('UFJ', 'NNP')]
# UFJ
# [('OAO', 'NNP'), ('Mobile', 'NNP'), ('Telesystems', 'NNP')]
# OAO
# [('USA', 'NNP')]
# USA
# [('Dresdner', 'NNP'), ('Kleinwort', 'NNP'), ('Wasserstein', 'NNP')]
# Dresdner
# [('Shenzhen', 'NNP')]
# Shenzhen
# [('Yantai', 'NNP')]
# Yantai
# [('US', 'NNP'), ('Agriculture', 'NNP'), ('Department', 'NNP')]
# US
# [('Yantai', 'NNP')]
# Yantai
# [('US', 'NNP'), ('Agriculture', 'NNP'), ('Department', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Rangers', 'NNPS')]
# Rangers
# [('UK', 'NNP')]
# UK
# [('London', 'NNP'), ('Stock', 'NNP'), ('Exchange', 'NNP')]
# London
# [('UK', 'NNP')]
# UK
# [('Federal', 'NNP'), ('Reserve', 'NNP')]
# Federal
# [('House', 'NNP'), ('Budget', 'NNP')]
# House
# [('Congress', 'NNP')]
# Congress
# [('Congress', 'NNP')]
# Congress
# [('Congress', 'NNP')]
# Congress
# [('US', 'NNP')]
# US
# [('UK', 'NNP'), ('Coal', 'NNP')]
# UK
# [('UK', 'NNP')]
# UK
# [('UK', 'NNP'), ('Coal', 'NNP')]
# UK
# [('Ministry', 'NNP')]
# Ministry
# [('Foreign', 'NNP'), ('Affairs', 'NNP')]
# Foreign
# [('Cabinet', 'NNP')]
# Cabinet
# [('GDP', 'NNP')]
# GDP
# [('GDP', 'NNP')]
# GDP
# [('US', 'NNP')]
# US
# [('Reuters', 'NNP')]
# Reuters
# [('Energy', 'NNP'), ('Merchant', 'NNP')]
# Energy
# [('US', 'NNP')]
# US
# [('BP', 'NNP')]
# BP
# [('Ministry', 'NNP')]
# Ministry
# [('METI', 'NNP')]
# METI
# [('UFJ', 'NNP'), ('Bank', 'NNP')]
# UFJ
# [('METI', 'NNP')]
# METI
# [('Nikkei', 'NNP')]
# Nikkei
# [('Parmalat', 'NNP'), ('Finanziaria', 'NNP')]
# Parmalat
# [('Parmalat', 'NNP'), ('Finanziaria', 'NNP')]
# Parmalat
# [('Parmalat', 'NNP')]
# Parmalat
# [('Parmalat', 'NNP')]
# Parmalat
# [('Parmalat', 'NNP')]
# Parmalat
# [('BMW', 'NNP')]
# BMW
# [('Oxford', 'NNP')]
# Oxford
# [('BMW', 'NNP')]
# BMW
# [('Mini', 'NNP')]
# Mini
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('Automotive', 'JJ'), ('News', 'NNP'), ('Europe', 'NNP')]
# Automotive
# [('Cooper', 'NNP')]
# Cooper
# [('Mini', 'NNP'), ('Convertible', 'NNP')]
# Mini
# [('Mini', 'NNP'), ('One', 'NNP')]
# Mini
# [('Mini', 'NNP')]
# Mini
# [('Mercedes', 'NNP'), ('Benz', 'NNP'), ('C180', 'NNP')]
# Mercedes
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('Mini', 'NNP')]
# Mini
# [('UK', 'NNP')]
# UK
# [('Phoenix', 'NNP')]
# Phoenix
# [('BMW', 'NNP')]
# BMW
# [('Oxford', 'NNP')]
# Oxford
# [('Mini', 'NNP')]
# Mini
# [('MG', 'NNP'), ('Rover', 'NNP')]
# MG
# [('SAIC', 'NNP')]
# SAIC
# [('Longbridge', 'NNP')]
# Longbridge
# [('MG', 'NNP'), ('Rover', 'NNP')]
# MG
# [('BMW', 'NNP')]
# BMW
# [('Nestle', 'NNP')]
# Nestle
# [('Americas', 'NNPS')]
# Americas
# [('Financial', 'NNP'), ('Times', 'NNP')]
# Financial
# [('GM', 'NNP')]
# GM
# [('Formula', 'NNP'), ('One', 'NNP')]
# Formula
# [('Mediobanca', 'NNP')]
# Mediobanca
# [('Maserati', 'NNP')]
# Maserati
# [('Financial', 'NNP'), ('Times', 'NNP')]
# Financial
# [('General', 'NNP'), ('Motors', 'NNPS')]
# General
# [('Development', 'NNP')]
# Development
# [('R', 'NNP')]
# R
# [('Enel', 'NNP')]
# Enel
# [('Reuters', 'NNP'), ('Revenues', 'NNP')]
# Reuters
# [('Reuters', 'NNP')]
# Reuters
# [('Canary', 'NNP'), ('Wharf', 'NNP')]
# Canary
# [('Hyundai', 'NNP'), ('Motor', 'NNP')]
# Hyundai
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('Rolls-Royce', 'NNP')]
# Rolls-Royce
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('UK', 'NNP')]
# UK
# [('Bank', 'NNP')]
# Bank
# [('National', 'NNP'), ('Statistics', 'NNPS')]
# National
# [('ONS', 'NNP')]
# ONS
# [('ONS', 'NNP')]
# ONS
# [('BoE', 'NNP')]
# BoE
# [('Bank', 'NNP')]
# Bank
# [('ONS', 'NNP')]
# ONS
# [('ONS', 'NNP')]
# ONS
# [('MPC', 'NNP')]
# MPC
# [('Bank', 'NNP')]
# Bank
# [('Monetary', 'JJ'), ('Policy', 'NNP'), ('Committee', 'NNP')]
# Monetary
# [('MPC', 'NNP')]
# MPC
# [('Bank', 'NNP')]
# Bank
# [('ONS', 'NNP')]
# ONS
# [('House', 'NNP')]
# House
# [('Lords', 'NNPS'), ('Economic', 'NNP'), ('Affairs', 'NNPS'), ('Committee', 'NNP')]
# Lords
# [('MPC', 'NNP')]
# MPC
# [('MPC', 'NNP')]
# MPC
# [('MPC', 'NNP')]
# MPC
# [('Newton', 'NNP'), ('Aycliffe', 'NNP')]
# Newton
# [('AEG', 'NNP')]
# AEG
# [('Frigidaire', 'NNP')]
# Frigidaire
# [('Worldcom', 'NNP')]
# Worldcom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('US', 'NNP')]
# US
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('MCI', 'NNP')]
# MCI
# [('MCI', 'NNP')]
# MCI
# [('Verizon', 'NNP'), ('Communications', 'NNPS')]
# Verizon
# [('American', 'JJ')]
# American
# [('International', 'NNP'), ('Group', 'NNP')]
# International
# [('AIG', 'NNP')]
# AIG
# [('McLennan', 'NNP')]
# McLennan
# [('UK', 'NNP')]
# UK
# [('National', 'NNP'), ('Statistics', 'NNPS')]
# National
# [('ONS', 'NNP')]
# ONS
# [('UK', 'NNP')]
# UK
# [('Bank', 'NNP')]
# Bank
# [('Monument', 'NNP')]
# Monument
# [('Reuters', 'NNS')]
# Reuters
# [('BoE', 'NNP')]
# BoE
# [('Multiplex', 'NNP'), ('Group', 'NNP')]
# Multiplex
# [('Wembley', 'NNP')]
# Wembley
# [('Wembley', 'NNP')]
# Wembley
# [('Goldman', 'NNP'), ('Sachs', 'NNP')]
# Goldman
# [('Reuters', 'NNP')]
# Reuters
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('SG', 'NNP'), ('Corporate', 'NNP')]
# SG
# [('Investment', 'NNP'), ('Banking', 'NNP')]
# Investment
# [('Nomura', 'NNP'), ('Securities', 'NNPS'), ('International', 'NNP')]
# Nomura
# [('Popular', 'NNP'), ('Securities', 'NNPS')]
# Popular
# [('BBC', 'NNP')]
# BBC
# [('Frankfurt', 'NNP')]
# Frankfurt
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('EU', 'NNP')]
# EU
# [('SARS', 'NNP')]
# SARS
# [('Association', 'NNP')]
# Association
# [('EU', 'NNP')]
# EU
# [('Ifo', 'NNP')]
# Ifo
# [('DZ', 'NNP')]
# DZ
# [('DaimlerChrysler', 'NNP')]
# DaimlerChrysler
# [('Volkswagen', 'NNP')]
# Volkswagen
# [('Ifo', 'NNP')]
# Ifo
# [('European', 'JJ'), ('Central', 'NNP'), ('Bank', 'NNP')]
# European
# [('FAO', 'NNP')]
# FAO
# [('UN', 'NNP')]
# UN
# [('Food', 'NNP')]
# Food
# [('Agriculture', 'NNP'), ('Organisation', 'NNP')]
# Agriculture
# [('FAO', 'NNP')]
# FAO
# [('Agricultural', 'NNP'), ('Commodity', 'NNP'), ('Markets', 'NNPS')]
# Agricultural
# [('FAO', 'NNP')]
# FAO
# [('FAO', 'NNP')]
# FAO
# [('World', 'NNP'), ('Trade', 'NNP'), ('Organisation', 'NNP')]
# World
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('FAO', 'NNP')]
# FAO
# [('Commerce', 'NNP')]
# Commerce
# [('DLF', 'NNP'), ('Builders', 'NNP')]
# DLF
# [('BBC', 'NNP')]
# BBC
# [('Foreign', 'NNP'), ('Investment', 'NNP')]
# Foreign
# [('CB', 'NNP')]
# CB
# [('BBC', 'NNP')]
# BBC
# [('Centre', 'NNP')]
# Centre
# [('CITU', 'NNP')]
# CITU
# [('FDI', 'NNP')]
# FDI
# [('Boeing', 'NNP')]
# Boeing
# [('Boeing', 'NNP')]
# Boeing
# [('GE', 'NNP')]
# GE
# [('Boeing', 'NNP')]
# Boeing
# [('International', 'NNP'), ('Airlines', 'NNPS')]
# International
# [('EVA', 'NNP')]
# EVA
# [('Highfields', 'NNP'), ('Capital', 'NNP'), ('Management', 'NNP')]
# Highfields
# [('CL', 'NNP')]
# CL
# [('Sapporo', 'NNP')]
# Sapporo
# [('LG', 'NNP'), ('Card', 'NNP')]
# LG
# [('Federal', 'NNP'), ('Statistics', 'NNPS')]
# Federal
# [('Volkswagen', 'NNP')]
# Volkswagen
# [('DaimlerChrysler', 'NNP')]
# DaimlerChrysler
# [('European', 'JJ'), ('Central', 'NNP'), ('Bank', 'NNP')]
# European
# [('ECB', 'NNP')]
# ECB
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('Turkcell', 'NNP')]
# Turkcell
# [('MTN', 'NNP')]
# MTN
# [('TAV', 'NNP')]
# TAV
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('EU', 'NNP')]
# EU
# [('G7', 'NNP'), ('Group', 'NNP')]
# G7
# [('World', 'NNP'), ('Bank', 'NNP')]
# World
# [('Intifada', 'NNP')]
# Intifada
# [('World', 'NNP'), ('Bank', 'NNP')]
# World
# [('US', 'NNP')]
# US
# [('VEB', 'NNP')]
# VEB
# [('CNPC', 'NNP')]
# CNPC
# [('CNPC', 'NNP')]
# CNPC
# [('VEB', 'NNP')]
# VEB
# [('CNPC', 'NNP')]
# CNPC
# [('US', 'NNP')]
# US
# [('CNPC', 'NNP')]
# CNPC
# [('General', 'NNP'), ('Motors', 'NNP')]
# General
# [('Fiat', 'NNP')]
# Fiat
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('DaimlerChrysler', 'NNP')]
# DaimlerChrysler
# [('Fiat', 'NNP')]
# Fiat
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('Sal', 'NNP'), ('Oppenheim', 'NNP'), ('Bank', 'NNP')]
# Sal
# [('Federal', 'NNP'), ('Trade', 'NNP'), ('Commission', 'NNP')]
# Federal
# [('ID', 'NNP')]
# ID
# [('ID', 'NNP')]
# ID
# [('PCs', 'NNS')]
# PCs
# [('PDVSA', 'NNP')]
# PDVSA
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('BMW', 'NNP')]
# BMW
# [('Mercedes', 'NNP'), ('Benz', 'NNP')]
# Mercedes
# [('DaimlerChrysler', 'NNP')]
# DaimlerChrysler
# [('Mercedes', 'NNP'), ('Benz', 'NNP')]
# Mercedes
# [('Mercedes', 'NNP')]
# Mercedes
# [('City', 'NNP')]
# City
# [('United', 'NNP'), ('Parcel', 'NNP'), ('Services', 'NNPS')]
# United
# [('UPS', 'NNP')]
# UPS
# [('GE', 'NNP'), ('Capital', 'NNP')]
# GE
# [('Mothercare', 'NNP')]
# Mothercare
# [('UPS', 'NNP')]
# UPS
# [('Deutsche', 'NNP')]
# Deutsche
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Yukos', 'NNP')]
# Yukos
# [('Gazprom', 'NNP')]
# Gazprom
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Bank', 'NNP')]
# Bank
# [('GDP', 'NNP')]
# GDP
# [('Bank', 'NNP')]
# Bank
# [('Bank', 'NNP')]
# Bank
# [('US', 'NNP'), ('Treasury', 'NNP')]
# US
# [('Inter-American', 'NNP'), ('Development', 'NNP'), ('Bank', 'NNP')]
# Inter-American
# [('Inter-American', 'JJ'), ('Development', 'NNP'), ('Bank', 'NNP')]
# Inter-American
# [('UK', 'NNP')]
# UK
# [('Bank', 'NNP')]
# Bank
# [('Bankers', 'NNP')]
# Bankers
# [('BoE', 'NNP')]
# BoE
# [('BBA', 'NNP')]
# BBA
# [('Bank', 'NNP')]
# Bank
# [('Chartered', 'NNP'), ('Institute', 'NNP')]
# Chartered
# [('CIPS', 'NNP')]
# CIPS
# [('PMI', 'NNP')]
# PMI
# [('PMI', 'NNP')]
# PMI
# [('CIPS', 'NNP')]
# CIPS
# [('CIPS', 'NNP')]
# CIPS
# [('UK', 'NNP')]
# UK
# [('Bank', 'NNP')]
# Bank
# [('Worldcom', 'NNP')]
# Worldcom
# [('Former', 'NNP'), ('Worldcom', 'NNP')]
# Former
# [('Worldcom', 'NNP')]
# Worldcom
# [('Worldcom', 'NNP')]
# Worldcom
# [('Worldcom', 'NNP')]
# Worldcom
# [('Worldcom', 'NNP')]
# Worldcom
# [('Worldcom', 'NNP')]
# Worldcom
# [('CEO', 'NNP')]
# CEO
# [('Metlife', 'NNP')]
# Metlife
# [('Citigroup', 'NNP')]
# Citigroup
# [('Citigroup', 'NNP')]
# Citigroup
# [('Travelers', 'NNP'), ('Life', 'NNP')]
# Travelers
# [('Metlife', 'NNP')]
# Metlife
# [('Citigroup', 'NNP')]
# Citigroup
# [('Metlife', 'NNP')]
# Metlife
# [('US', 'NNP')]
# US
# [('Metlife', 'NNP')]
# Metlife
# [('Metlife', 'NNP')]
# Metlife
# [('Citibank', 'NNP')]
# Citibank
# [('Metlife', 'NNP')]
# Metlife
# [('Gartmore', 'NNP')]
# Gartmore
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('JPMorgan', 'NNP')]
# JPMorgan
# [('US', 'NNP'), ('Treasury', 'NNP')]
# US
# [('European', 'NNP'), ('Union', 'NNP')]
# European
# [('FNSEA', 'NNP')]
# FNSEA
# [('Associated', 'NNP')]
# Associated
# [('Yukos', 'NNP')]
# Yukos
# [('MPs', 'NNP')]
# MPs
# [('MPs', 'NNP')]
# MPs
# [('Turkcell', 'NNP')]
# Turkcell
# [('Parliament', 'NNP')]
# Parliament
# [('TAV', 'NNP')]
# TAV
# [('UK', 'NNP')]
# UK
# [('Luxembourg', 'NNP')]
# Luxembourg
# [('GDP', 'NNP')]
# GDP
# [('GDP', 'NNP')]
# GDP
# [('Commerce', 'NNP'), ('Department', 'NNP')]
# Commerce
# [('R', 'NNP')]
# R
# [('US', 'NNP')]
# US
# [('Republic', 'NNP')]
# Republic
# [('US', 'NNP'), ('Treasury', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('Commerzbank', 'NNP')]
# Commerzbank
# [('US', 'NNP')]
# US
# [('IMF', 'NNP')]
# IMF
# [('International', 'NNP'), ('Monetary', 'NNP'), ('Fund', 'NNP')]
# International
# [('Financial', 'NNP'), ('Times', 'NNPS'), ('Deutschland', 'NNP')]
# Financial
# [('IMF', 'NNP')]
# IMF
# [('IMF', 'NNP')]
# IMF
# [('FT', 'NNP')]
# FT
# [('IMF', 'NNP')]
# IMF
# [('IMF', 'NNP')]
# IMF
# [('Organisation', 'NNP')]
# Organisation
# [('Economic', 'NNP')]
# Economic
# [('Development', 'NNP')]
# Development
# [('ABN', 'NNP'), ('Amro', 'NNP')]
# ABN
# [('General', 'NNP'), ('Motors', 'NNPS')]
# General
# [('GM', 'NNP')]
# GM
# [('Ford', 'NNP')]
# Ford
# [('Ford', 'NNP')]
# Ford
# [('SUVs', 'NNP')]
# SUVs
# [('Pontiac', 'NNP'), ('G6', 'NNP')]
# Pontiac
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('Ford', 'NNP')]
# Ford
# [('US', 'NNP')]
# US
# [('DaimlerChrysler', 'NNP')]
# DaimlerChrysler
# [('US', 'NNP')]
# US
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('WorldCom', 'NNP')]
# WorldCom
# [('MCI', 'NNP')]
# MCI
# [('Reserve', 'NNP'), ('Bank', 'NNP')]
# Reserve
# [('Bank', 'NNP')]
# Bank
# [('Bank', 'NNP')]
# Bank
# [('GDP', 'NNP')]
# GDP
# [('Bank', 'NNP')]
# Bank
# [('Reserve', 'NNP'), ('Bank', 'NNP')]
# Reserve
# [('Bank', 'NNP')]
# Bank
# [('Commonwealth', 'NNP'), ('Bank', 'NNP')]
# Commonwealth
# [('US', 'NNP')]
# US
# [('Securities', 'NNPS')]
# Securities
# [('Exchange', 'NNP'), ('Commission', 'NNP')]
# Exchange
# [('SEC', 'NNP')]
# SEC
# [('SEC', 'NNP')]
# SEC
# [('US', 'NNP')]
# US
# [('McLennan', 'NNP')]
# McLennan
# [('MMC', 'NNP')]
# MMC
# [('MMC', 'NNP'), ('Capital', 'NNP')]
# MMC
# [('Trident', 'NNP'), ('Funds', 'NNPS')]
# Trident
# [('US', 'NNP')]
# US
# [('US', 'NNP')]
# US
# [('US', 'NNP'), ('Court', 'NNP')]
# US
# [('District', 'NNP')]
# District
# [('Altria', 'NNP'), ('Group', 'NNP')]
# Altria
# [('RJ', 'NNP'), ('Reynolds', 'NNP'), ('Tobacco', 'NNP')]
# RJ
# [('Philip', 'NNP'), ('Morris', 'NNP')]
# Philip
# [('BBC', 'NNP')]
# BBC
# [('Fiat', 'NNP'), ('Powertrain', 'NNP')]
# Fiat
# [('General', 'NNP'), ('Motors', 'NNPS')]
# General
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('Reuters', 'NNP')]
# Reuters
# [('Reuters', 'NNP')]
# Reuters
# [('Fiat', 'NNP')]
# Fiat
# [('GTV', 'NNP')]
# GTV
# [('GT', 'NNP')]
# GT
# [('General', 'NNP'), ('Motors', 'NNPS')]
# General
# [('Cadillac', 'NNP')]
# Cadillac
# [('GM', 'NNP'), ('Europe', 'NNP')]
# GM
# [('Saab', 'NNP')]
# Saab
# [('GM', 'NNP')]
# GM
# [('GM', 'NNP')]
# GM
# [('BMW', 'NNP')]
# BMW
# [('Mercedes', 'NNP')]
# Mercedes
# [('Toyota', 'NNP')]
# Toyota
# [('US', 'NNP')]
# US
# [('Mercedes', 'NNP'), ('Benz', 'NNP')]
# Mercedes
# [('BMW', 'NNP')]
# BMW
# [('Saab', 'NNP')]
# Saab
# [('GM', 'NNP')]
# GM
# [('UK', 'NNP')]
# UK
# [('BBC', 'NNP'), ('News', 'NNP')]
# BBC
# [('GM', 'NNP')]
# GM
# [('Vauxhall', 'NNP')]
# Vauxhall
# [('GM', 'NNP')]
# GM
# [('Vauxhall', 'NNP')]
# Vauxhall
# {'Children', 'TAV', 'Rank', 'One', 'Bank', 'SG', 'AA', 'NEC', 'Hereford', 'PCs', 'Ask', 'Commonwealth', 'UBS', 'Intifada', 'ERM', 'Sox', 'Liberal', 'ABN', 'McConnell', 'Session', 'Pinewood', 'Parliament', 'SURF', 'Defra', 'MPC', 'SARS', 'GCSEs', 'Hazards', 'Board', 'PDVSA', 'Congress', 'MEP', 'DLF', 'Public', 'Nato', 'Defence', 'Monument', 'Formula', 'Gypsies', 'Chartered', 'Warner', 'Sumitomo', 'Cadillac', 'Bicester', 'Frankfurt', 'GT', 'Union', 'MP', 'Anglican', 'ECB', 'Organisation', 'Venezuelan', 'Citibank', 'Merionnydd', 'HRH', 'GP', 'Sindh', 'Dresdner', 'Queen', 'Commerzbank', 'IATA', 'Development', 'Standards', 'ERAA', 'Transport', 'Road', 'UAF', 'TB', 'DVDs', 'Travelers', 'Labour', 'Warwick', 'ITV', 'Hansard', 'Doha', 'Margaret', 'Sri', 'Nomura', 'Mothercare', 'Welsh', 'Gateshead', 'NCB', 'Yantai', 'University', 'Llyn', 'Metlife', 'Muslim', 'Reuters', 'IXIS', 'Special', 'Automotive', 'CommunicateResearch', 'International', 'Bankers', 'WorldCom', 'TUC', 'Health', 'Commander', 'Security', 'Highlands', 'Veritas', 'Hypovereinsbank', 'Commission', 'Family', 'Westminster', 'Countryside', 'Newsnight', 'Herald', 'Common', 'Bayleaf', 'Volkswagen', 'Nairobi', 'SNP', 'Leisure', 'MacDonald', 'Quentin', 'MG', 'Sellafield', 'Parliamentary', 'Commerce', 'UKIP', 'Child', 'ISG', 'Nazi', 'Refugee', 'GMC', 'SAIC', 'Sterling', 'National', 'Gloucestershire', 'Hard', 'Altria', 'Civil', 'Culture', 'Hollinger', 'Toyota', 'SUV', 'Hunting', 'Duke', 'SGC', 'Royal', 'Nationality', 'Traveller', 'Times', 'Ifo', 'FT', 'BA', 'Lung', 'Financial', 'CBI', 'Cabinet', 'Dimension', 'ILW', 'NHTSA', 'RJ', 'MI6', 'Federation', 'HMS', 'Czech', 'Eurosceptic', 'METI', 'Prince', 'LVMH', 'BAC', 'Nazis', 'ICT', 'MTFG', 'Turkcell', 'Saab', 'Parmalat', 'Reynolds', 'Fairford', 'Postbridge', 'Survivors', 'Ulster', 'DZ', 'Scottish', 'Law', 'Exchange', 'IHRC', 'Guildford', 'BMA', 'ISEQ', 'ONS', 'Lib', 'TGWU', 'Trident', 'Pontiac', 'MCI', 'Securities', 'Matrix', 'Popular', 'IMF', 'YouGov', 'DaimlerChrysler', 'Associated', 'IEA', 'London', 'CSA', 'Allander', 'Authority', 'Mini', 'Nikkei', 'CITU', 'Fiat', 'Vauxhall', 'Inter-American', 'GTV', 'Belmarsh', 'MI5', 'Windsor', 'Ministry', 'Princess', 'Bordesley', 'Hyundai', 'BNP', 'TimeWarner', 'Evangelical', 'Zimbabwe', 'Sapporo', 'Nestle', 'Mental', 'IOC', 'BP', 'Creek', 'Club2School', 'Leicestershire', 'Shenzhen', 'AIG', 'Quarterly', 'Election', 'Merseyside', 'GE', 'Mercedes', 'WPP', 'Club', 'FNSEA', 'Reserve', 'Philip', 'CL', 'RAF', 'Beaufort', 'Chevrolet', 'VEB', 'Social', 'Small', 'Immigration', 'OECD', 'BMO', 'Luxembourg', 'Community', 'AM', 'Chancellor', 'Frigidaire', 'Gazprom', 'Mitsubishi', 'Salford', 'PMI', 'Euston', 'Yukos', 'Verizon', 'Buckingham', 'House', 'Committee', 'Guardian', 'News', 'Tuberculosis', 'FDI', 'Lord', 'Gartmore', 'Sal', 'G7', 'Ivory', 'Economic', 'Hatfield', 'Terrence', 'SIAC', 'QC', 'Conservative', 'Seagram', 'Defense', 'Archbishop', 'Canary', 'Appeal', 'Lords', 'Tories', 'Rangers', 'Nissan', 'IRA', 'Downing', 'BBC', 'G20', 'Enel', 'Americas', 'Commons', 'ELAA', 'Vestey', 'Grey', 'Oxford', 'Heathrow', 'MSPs', 'Journalists', 'BMW', 'Goldman', 'SEC', 'Blunkett', 'EDS', 'SUVs', 'Lehman', 'Barclay', 'PE', 'Rosneft', 'Investment', 'Cooper', 'Tata', 'Human', 'CS2', 'Daiwa', 'NOP', 'RAC', 'UFJ', 'Department', 'Rolls-Royce', 'PM', 'FAO', 'MPs', 'MTN', 'ClearView', 'Sunovate', 'EVA', 'CEO', 'UK', 'Former', 'General', 'LG', 'Waverley', 'Food', 'GMB', 'Bush', 'BBA', 'Key', 'FIFA', 'Pentagon', 'Maserati', 'Labor', 'OAO', 'NatWest', 'Metropolitan', 'Powys', 'US', 'GDP', 'Mecca', 'Environmental', 'HIV', 'Maze', 'SDLP', 'Make', 'Commissioner', 'Swansea', 'Respect', 'Highfields', 'Wembley', 'European', 'Monetary', 'NUJ', 'Foreign', 'Green', 'Sun', 'Ford', 'Sentencing', 'Ogilvy', 'GM', 'Mittal', 'Loch', 'Catholic', 'Disability', 'NAO', 'DaimlerChrylser', 'English', 'EC', 'Energy', 'Manchester', 'Terrorism', 'Phoenix', 'AEG', 'Shrewsbury', 'Hospital', 'UPS', 'Inland', 'League', 'Washington', 'Centre', 'Line', 'AOL' ...

# %%
for organization in org:
    combined_matches = re.findall(r".{0,100}Sweden.{0,100}" + organization + r".{0,100}", corpusText)
    if combined_matches :
      print('\nCombined Matches for', organization, ':', combined_matches)
# Out:
# Combined Matches for Sellafield : ['rmed guard. Intermediate waste from countries such as Japan, Germany, Spain, Italy, Switzerland and Sweden will be stored permanently in the UK. At the moment, this waste is stored at Sellafield, in Cumbria, in the form of glass bricks, untreated liquid waste or solid material in drums. In a s']
#
# Combined Matches for ICT : ['ried out independently by consultants Booz Allen Hamilton and HI Europe, placed the UK third behind Sweden and Ireland for business use of ICT.']
#
# Combined Matches for Saab : ["Neither will the announcement be seen as unalloyed good news in Sweden, since it reflects Saab's failure to make significant inroads into the lucrative European luxury car market. For years, Saa", 'Bringing Cadillac production to Sweden should help introduce desperately-needed scale to the Saab factory, which currently produces fewer than 130,000 cars per year. That is about half of what majo']
#
# Combined Matches for UK : ['rmed guard. Intermediate waste from countries such as Japan, Germany, Spain, Italy, Switzerland and Sweden will be stored permanently in the UK. At the moment, this waste is stored at Sellafield, in Cumbria, in the form of glass bricks, untrea']
#
# Combined Matches for US : ["GM's plans to build the American marque in Sweden is part of its efforts to push it as an alternative luxury brand for European drivers. In the US, it has long been established as an upmarket brand - even the presidential limousine carries the ba"]
#
# Combined Matches for European : ["Neither will the announcement be seen as unalloyed good news in Sweden, since it reflects Saab's failure to make significant inroads into the lucrative European luxury car market. For years, Saab has consistently said it is competing head-on with BMW, Mercedes", "GM's plans to build the American marque in Sweden is part of its efforts to push it as an alternative luxury brand for European drivers. In the US, it has long been established as an upmarket brand - even the presidential limou"]
